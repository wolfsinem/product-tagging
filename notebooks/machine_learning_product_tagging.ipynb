# %% [markdown]
# # Product tagging using Machine Learning
#
# ---

# %%
# Data processing
import pandas as pd
import numpy as np
from collections import Counter

# Visualisation
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import seaborn as sns

# Language processing
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import nltk
# nltk.download('stopwords') # if you haven't downloaded this yet, you need to now.


# Machine Learning - model training
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer

from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

from sklearn.multiclass import OneVsRestClassifier

from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
filepath = '/Users/wolfsinem/product-tagging/data/flipkart_com-ecommerce_sample.csv'
df = pd.read_csv((filepath))

# %%
df.head(1)
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
#
#                           product_name  \
# 0  Alisha Solid Women's Cycling Shorts
#
#                                product_category_tree               pid  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
#
#    retail_price  discounted_price  \
# 0         999.0             379.0
#
#                                                image  is_FK_Advantage_product  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...                    False
#
#                                          description       product_rating  \
# 0  Key Features of Alisha Solid Women's Cycling S...  No rating available
#
#         overall_rating   brand  \
# 0  No rating available  Alisha
#
#                               product_specifications
# 0  {"product_specification"=>[{"key"=>"Number of ...

# %%
model_df = df[['product_name','description']]

# %%
model_df.shape
# Out:
# (20000, 2)

# %%
pd.options.mode.chained_assignment = None 
model_df['tags'] = ""

# %%
model_df
# Out:
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# 1          FabHomeDecor Fabric Double Sofa Bed
# 2                                   AW Bellies
# 3          Alisha Solid Women's Cycling Shorts
# 4        Sicons All Purpose Arnica Dog Shampoo
# ...                                        ...
# 19995           WallDesign Small Vinyl Sticker
# 19996  Wallmantra Large Vinyl Stickers Sticker
# 19997  Elite Collection Medium Acrylic Sticker
# 19998  Elite Collection Medium Acrylic Sticker
# 19999  Elite Collection Medium Acrylic Sticker
#
#                                              description tags
# 0      Key Features of Alisha Solid Women's Cycling S...
# 1      FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2      Key Features of AW Bellies Sandals Wedges Heel...
# 3      Key Features of Alisha Solid Women's Cycling S...
# 4      Specifications of Sicons All Purpose Arnica Do...
# ...                                                  ...  ...
# 19995  Buy WallDesign Small Vinyl Sticker for Rs.730 ...
# 19996  Buy Wallmantra Large Vinyl Stickers Sticker fo...
# 19997  Buy Elite Collection Medium Acrylic Sticker fo...
# 19998  Buy Elite Collection Medium Acrylic Sticker fo...
# 19999  Buy Elite Collection Medium Acrylic Sticker fo...
#
# [20000 rows x 3 columns]

# %% [markdown]
# #### Set all strings to lowercase

# %%
df['product_name'].str.lower()
df['description'].str.lower()
# Out:
# 0        key features of alisha solid women's cycling s...
# 1        fabhomedecor fabric double sofa bed (finish co...
# 2        key features of aw bellies sandals wedges heel...
# 3        key features of alisha solid women's cycling s...
# 4        specifications of sicons all purpose arnica do...
#                                ...
# 19995    buy walldesign small vinyl sticker for rs.730 ...
# 19996    buy wallmantra large vinyl stickers sticker fo...
# 19997    buy elite collection medium acrylic sticker fo...
# 19998    buy elite collection medium acrylic sticker fo...
# 19999    buy elite collection medium acrylic sticker fo...
# Name: description, Length: 20000, dtype: object

# %%
test_string = model_df['description'][0]
test_string
# Out:
# "Key Features of Alisha Solid Women's Cycling Shorts Cotton Lycra Navy, Red, Navy,Specifications of Alisha Solid Women's Cycling Shorts Shorts Details Number of Contents in Sales Package Pack of 3 Fabric Cotton Lycra Type Cycling Shorts General Details Pattern Solid Ideal For Women's Fabric Care Gentle Machine Wash in Lukewarm Water, Do Not Bleach Additional Details Style Code ALTHT_3P_21 In the Box 3 shorts"

# %% [markdown]
# ### Function to create tags

# %%
def tokenize_string(sentence):  
    tokenizer = nltk.RegexpTokenizer(r"\w+")
    new_words = tokenizer.tokenize(sentence)
    new_words = [token.lower() for token in new_words] # set to a lower case
    
    stop_words = set(stopwords.words('english')) 
    manual_filtered_words = {'details','fabric','key','features','sales','number','contents','type','general', 'specifications'}

    filtered_sentence = [w for w in new_words if not w in stop_words and not w in manual_filtered_words]
    count_terms = Counter(filtered_sentence).most_common(10) # fill e.g. (5) for most common 5 terms
    return [item[0] for item in count_terms] # this function extracts the first element of each sublist, so only the terms and not how many times it occured

# %% [markdown]
# #### Generating tags with the above function

# %%
term_lists = tokenize_string(test_string)
term_lists
# Out:
# ['shorts',
#  'solid',
#  'women',
#  'cycling',
#  'alisha',
#  'cotton',
#  'lycra',
#  'navy',
#  '3',
#  'red']

# %% [markdown]
# As you can see there are some numbers being used as tags. We will take these out.

# %% [markdown]
# #### Now we need to for-loop this so the function generates tags for each of the comments

# %%
# this function takes out every number within a string because we don't need it as tags since it doesnt give any context
# print([x for x in token_lists[] if not any(c.isdigit() for c in x)])

# %%
token_lists = []
for i in model_df['description']:
    token_lists.append([x for x in tokenize_string(str((i))) if not any(c.isdigit() for c in x)])

# %%
token_lists
# Out:
# [['shorts',
#   'solid',
#   'women',
#   'cycling',
#   'alisha',
#   'cotton',
#   'lycra',
#   'navy',
#   'red'],
#  ['product',
#   'sofa',
#   'color',
#   'bed',
#   'warranty',
#   'material',
#   'avoid',
#   'double',
#   'black',
#   'finish'],
#  ['aw',
#   'bellies',
#   'heel',
#   'material',
#   'casual',
#   'warranty',
#   'pair',
#   'shoes',
#   'use',
#   'shoe'],
#  ['shorts',
#   'solid',
#   'women',
#   'cycling',
#   'alisha',
#   'cotton',
#   'lycra',
#   'black',
#   'red'],
#  ['sicons',
#   'arnica',
#   'dog',
#   'purpose',
#   'shampoo',
#   'ml',
#   'pet',
#   'brand',
#   'quantity'],
#  ['paper',
#   'crystal',
#   'weight',
#   'gandhi',
#   'finish',
#   'silver',
#   'eternal',
#   'super',
#   'series',
#   'weights'],
#  ['shorts',
#   'solid',
#   'women',
#   'cycling',
#   'alisha',
#   'cotton',
#   'lycra',
#   'red',
#   'navy'],
#  ['product',
#   'sofa',
#   'color',
#   'bed',
#   'warranty',
#   'material',
#   'avoid',
#   'double',
#   'brown',
#   'finish'],
#  ['casuals',
#   'dilli',
#   'bazaaar',
#   'bellies',
#   'corporate',
#   'material',
#   'occasion',
#   'ethnic',
#   'casual',
#   'party'],
#  ['shorts',
#   'solid',
#   'women',
#   'cycling',
#   'alisha',
#   'cotton',
#   'lycra',
#   'black',
#   'white'],
#  ['ladela',
#   'bellies',
#   'color',
#   'black',
#   'best',
#   'material',
#   'brand',
#   'price',
#   'rs'],
#  ['carrel',
#   'printed',
#   'women',
#   'swimwear',
#   'swim',
#   'swimlycra',
#   'brand',
#   'black',
#   'white',
#   'water'],
#  ['sicons', 'dog', 'purpose', 'tea', 'tree', 'shampoo', 'ml', 'pet', 'brand'],
#  ['shorts',
#   'solid',
#   'women',
#   'cycling',
#   'alisha',
#   'cotton',
#   'lycra',
#   'black',
#   'white'],
#  ['bottle',
#   'pack',
#   'package',
#   'freelance',
#   'vacuum',
#   'bottles',
#   'ml',
#   'green'],
#  ['shorts',
#   'solid',
#   'women',
#   'cycling',
#   'alisha',
#   'cotton',
#   'lycra',
#   'white',
#   'black'],
#  ['product',
#   'sofa',
#   'color',
#   'bed',
#   'warranty',
#   'material',
#   'avoid',
#   'double',
#   'purple',
#   'finish'],
#  ['style',
#   'foot',
#   'bellies',
#   'ballerina',
#   'shoes',
#   'casual',
#   'flats',
#   'price',
#   'rs'],
#  ['carrel',
#   'printed',
#   'women',
#   'swimwear',
#   'swim',
#   'swimlycra',
#   'brand',
#   'white',
#   'water',
#   'comfort'],
#  ['product',
#   'sofa',
#   'color',
#   'bed',
#   'warranty',
#   'material',
#   'avoid',
#   'double',
#   'brown',
#   'finish'],
#  ['sicons',
#   'dog',
#   'conditioning',
#   'conditoner',
#   'shampoo',
#   'ml',
#   'pet',
#   'brand',
#   'quantity'],
#  ['alisha',
#   'solid',
#   'women',
#   'cycling',
#   'shorts',
#   'online',
#   'buy',
#   'black',
#   'white',
#   'navy'],
#  ['shirt',
#   'printed',
#   'boy',
#   'round',
#   'neck',
#   'pack',
#   'sleeve',
#   'colors',
#   'dongli'],
#  ['women',
#   'clogs',
#   'swagga',
#   'occasion',
#   'ethnic',
#   'material',
#   'leather',
#   'color',
#   'brown',
#   'heel'],
#  ['rubber', 'kennel', 'dumbell', 'bell', 'small', 'toy', 'dog', 'buy', 'rs'],
#  ['glus',
#   'wedding',
#   'lingerie',
#   'set',
#   'online',
#   'buy',
#   'turquoise',
#   'rs',
#   'india'],
#  ['veelys', 'shiny', 'white', 'quad', 'roller', 'skates', 'size', 'uk'],
#  ['vanity',
#   'case',
#   'bulaky',
#   'jewellery',
#   'buy',
#   'rs',
#   'online',
#   'best',
#   'prices'],
#  ['fdt',
#   'women',
#   'leggings',
#   'online',
#   'buy',
#   'parrot',
#   'green',
#   'rs',
#   'india'],
#  ['madcaps', 'men', 'cargos', 'online', 'buy', 'green', 'rs', 'india'],
#  ['pot',
#   'bengal',
#   'blooms',
#   'artificial',
#   'rose',
#   'plant',
#   'cm',
#   'assorted',
#   'multicolor'],
#  ['choli',
#   'indcrown',
#   'stitched',
#   'lehenga',
#   'material',
#   'semi',
#   'lehnga',
#   'net',
#   'embroidered',
#   'also'],
#  ['notebook',
#   'shopmania',
#   'spiral',
#   'bound',
#   'multicolor',
#   'gsm',
#   'cover',
#   'inch',
#   'music'],
#  ['notebook',
#   'shopmania',
#   'spiral',
#   'bound',
#   'multicolor',
#   'gsm',
#   'cover',
#   'inch',
#   'music'],
#  ['tiara', 'diaries', 'notebook', 'hard', 'bound', 'coffee'],
#  ['waistcoat',
#   'embroidered',
#   'women',
#   'kajci',
#   'pattern',
#   'ideal',
#   'art',
#   'silk',
#   'box',
#   'additional'],
#  ['bag', 'x', 'security', 'bags', 'pod', 'jacket', 'courier', 'packman'],
#  ['embroidered',
#   'women',
#   'waistcoat',
#   'pick',
#   'pocket',
#   'pattern',
#   'occasion',
#   'casual',
#   'ideal',
#   'lining'],
#  ['silk',
#   'potli',
#   'multicolor',
#   'angelfish',
#   'potali',
#   'code',
#   'price',
#   'rs',
#   'made'],
#  ['dungaree',
#   'boy',
#   'oye',
#   'top',
#   'package',
#   'pack',
#   'cotton',
#   'pattern',
#   'solid'],
#  ['canvas',
#   'nuride',
#   'shoes',
#   'material',
#   'occasion',
#   'casual',
#   'color',
#   'red',
#   'heel',
#   'height'],
#  ['cm', 'square', 'wall', 'paper', 'mache', 'om', 'shivakriti', 'clock'],
#  ['magnetic', 'window', 'himmlisch', 'sun', 'shade', 'side', 'heat', 'car'],
#  ['bnc', 'wire', 'rapter', 'connector', 'pack', 'silver', 'quality', 'used'],
#  ['kurta',
#   'printed',
#   'women',
#   'straight',
#   'neck',
#   'vishudh',
#   'sleeve',
#   'sleeveless',
#   'package',
#   'pack'],
#  ['kurta',
#   'printed',
#   'women',
#   'straight',
#   'neck',
#   'vishudh',
#   'sleeve',
#   'sleeveless',
#   'package',
#   'pack'],
#  ['kurta',
#   'printed',
#   'women',
#   'anarkali',
#   'sleeve',
#   'neck',
#   'vishudh',
#   'half',
#   'package',
#   'pack'],
#  ['wireless',
#   'sensor',
#   'motion',
#   'buildtrack',
#   'pir',
#   'one',
#   'switch',
#   'control',
#   'switches',
#   'security'],
#  ['pump',
#   'single',
#   'phase',
#   'system',
#   'skayvon',
#   'summersible',
#   'controller',
#   'wired',
#   'sensor',
#   'security'],
#  ['straight',
#   'solid',
#   'women',
#   'kurta',
#   'masara',
#   'kurti',
#   'pattern',
#   'cotton',
#   'sleeve',
#   'green'],
#  ['kurta',
#   'printed',
#   'women',
#   'straight',
#   'neck',
#   'vishudh',
#   'sleeve',
#   'sleeveless',
#   'package',
#   'pack'],
#  ['bnc', 'wire', 'rapter', 'connector', 'pack', 'silver', 'quality', 'used'],
#  ['pump',
#   'three',
#   'phase',
#   'system',
#   'skayvon',
#   'submersibble',
#   'controller',
#   'wired',
#   'sensor',
#   'security'],
#  ['kurta',
#   'printed',
#   'women',
#   'straight',
#   'neck',
#   'vishudh',
#   'sleeve',
#   'sleeveless',
#   'package',
#   'pack'],
#  ['warranty',
#   'mixer',
#   'product',
#   'power',
#   'behringer',
#   'xenyx',
#   'analog',
#   'sound'],
#  ['straight',
#   'kurta',
#   'printed',
#   'women',
#   'vishudh',
#   'black',
#   'grey',
#   'neck',
#   'sleeve',
#   'sleeveless'],
#  ['kurta',
#   'printed',
#   'women',
#   'straight',
#   'neck',
#   'vishudh',
#   'sleeve',
#   'sleeveless',
#   'package',
#   'pack'],
#  ['straight',
#   'solid',
#   'women',
#   'kurta',
#   'masara',
#   'kurti',
#   'pattern',
#   'cotton',
#   'sleeve',
#   'green'],
#  ['straight',
#   'kurta',
#   'solid',
#   'women',
#   'masara',
#   'cotton',
#   'sleeve',
#   'red',
#   'price',
#   'rs'],
#  ['cardigan',
#   'roadster',
#   'men',
#   'zipper',
#   'solid',
#   'acrylic',
#   'full',
#   'closure',
#   'casual'],
#  ['kurta',
#   'printed',
#   'women',
#   'straight',
#   'neck',
#   'vishudh',
#   'sleeve',
#   'sleeveless',
#   'package',
#   'pack'],
#  ['embroidered',
#   'women',
#   'straight',
#   'kurta',
#   'neck',
#   'noor',
#   'rayon',
#   'sleeve',
#   'elegant'],
#  ['straight',
#   'solid',
#   'women',
#   'kurta',
#   'masara',
#   'kurti',
#   'pattern',
#   'cotton',
#   'sleeve',
#   'pink'],
#  ['straight',
#   'kurta',
#   'printed',
#   'women',
#   'vishudh',
#   'plum',
#   'pink',
#   'neck',
#   'sleeve',
#   'sleeveless'],
#  ['kurta',
#   'printed',
#   'women',
#   'line',
#   'sleeve',
#   'libas',
#   'pattern',
#   'ideal',
#   'occasion',
#   'party'],
#  ['kurta',
#   'printed',
#   'women',
#   'anarkali',
#   'sleeve',
#   'libas',
#   'package',
#   'pack'],
#  ['straight',
#   'kurta',
#   'solid',
#   'women',
#   'masara',
#   'floral',
#   'bold',
#   'print',
#   'allow',
#   'select'],
#  ['chest',
#   'pads',
#   'right',
#   'handed',
#   'hrs',
#   'ultimate',
#   'boy',
#   'white',
#   'material',
#   'price'],
#  ['belt',
#   'brown',
#   'men',
#   'casual',
#   'genuine',
#   'leather',
#   'code',
#   'vermello',
#   'reversible'],
#  ['thigh',
#   'pads',
#   'right',
#   'handed',
#   'hrs',
#   'club',
#   'boy',
#   'white',
#   'pad',
#   'material'],
#  ['belt',
#   'black',
#   'genuine',
#   'leather',
#   'ligans',
#   'ny',
#   'men',
#   'formal',
#   'buckle',
#   'shiney'],
#  ['curtain',
#   'polyester',
#   'eyelet',
#   'door',
#   'elegance',
#   'multicolor',
#   'abstract',
#   'cm'],
#  ['sandal',
#   'liza',
#   'women',
#   'wedges',
#   'pair',
#   'material',
#   'occasion',
#   'casual',
#   'formal',
#   'party'],
#  ['elbow',
#   'pads',
#   'right',
#   'handed',
#   'hrs',
#   'ultimate',
#   'boy',
#   'white',
#   'material',
#   'price'],
#  ['bath',
#   'towel',
#   'sathiyas',
#   'cotton',
#   'red',
#   'yellow',
#   'blue',
#   'design',
#   'model'],
#  ['chest',
#   'pads',
#   'right',
#   'handed',
#   'material',
#   'hrs',
#   'ultimate',
#   'men',
#   'white',
#   'inner'],
#  ['towel', 'face', 'set', 'eurospa', 'cotton', 'terry', 'size', 'inch'],
#  ['cm',
#   'bedsheet',
#   'sheet',
#   'royal',
#   'pillow',
#   'cover',
#   'cotton',
#   'flat',
#   'inch',
#   'santosh'],
#  ['panel',
#   'casedeal',
#   'microsoft',
#   'nokia',
#   'lumia',
#   'back',
#   'white',
#   'brand',
#   'model'],
#  ['printed',
#   'shirt',
#   'women',
#   'casual',
#   'orange',
#   'sleeve',
#   'mario',
#   'gotze',
#   'fit',
#   'slim'],
#  ['sheet',
#   'cm',
#   'cotton',
#   'bedsheet',
#   'bed',
#   'pillow',
#   'cover',
#   'jaipur',
#   'print',
#   'king'],
#  ['coin', 'bank', 'shilpi', 'brown', 'box', 'package'],
#  ['sheet',
#   'cm',
#   'cotton',
#   'bed',
#   'pillow',
#   'cover',
#   'jaipur',
#   'print',
#   'king'],
#  ['baby',
#   'boy',
#   'combo',
#   'fit',
#   'colors',
#   'babeezworld',
#   'dungaree',
#   'apparel',
#   'primary',
#   'product'],
#  ['cm',
#   'redbag',
#   'eight',
#   'armed',
#   'goddess',
#   'sherawali',
#   'maa',
#   'showpiece'],
#  ['mg', 'gainers', 'information', 'proence', 'weight', 'mass', 'unflavored'],
#  ['discountgod',
#   'men',
#   'checkered',
#   'casual',
#   'shirt',
#   'online',
#   'buy',
#   'blood',
#   'red',
#   'rs'],
#  ['silver',
#   'streak',
#   'men',
#   'printed',
#   'casual',
#   'denim',
#   'shirt',
#   'online',
#   'buy',
#   'blue'],
#  ['cobra', 'paris', 'analog', 'watch', 'men', 'boys', 'buy', 'online', 'rs'],
#  ['boots', 'ten', 'women', 'black', 'knee', 'length', 'price', 'rs'],
#  ['g', 'bk', 'aries', 'gold', 'analog', 'watch', 'men', 'boys', 'buy'],
#  ['carlton', 'boots', 'buy', 'cll', 'rs', 'flipkart', 'com', 'genuine'],
#  ['maserati', 'time', 'analog', 'watch', 'boys', 'buy', 'online', 'rs'],
#  ['display',
#   'brand',
#   'warranty',
#   'case',
#   'dial',
#   'strap',
#   'hour',
#   'vizion',
#   'cold',
#   'digital'],
#  ['camerii',
#   'elegance',
#   'analog',
#   'watch',
#   'men',
#   'boys',
#   'buy',
#   'online',
#   'rs'],
#  ['reckler',
#   'slim',
#   'fit',
#   'men',
#   'jeans',
#   'online',
#   'buy',
#   'light',
#   'blue',
#   'shiny'],
#  ['quechua', 'arpenaz', 'novadry', 'boots', 'buy', 'nu', 'rs', 'flipkart'],
#  ['colat', 'sheen', 'analog', 'watch', 'men', 'women', 'boys', 'girls', 'buy'],
#  ['steppings', 'trendy', 'boots', 'buy', 'xf', 'rs', 'flipkart', 'com'],
#  ['rochees', 'analog', 'watch', 'boys', 'buy', 'online', 'rs', 'india'],
#  ['watch',
#   'stylish',
#   'analog',
#   'bombarded',
#   'complimenting',
#   'glances',
#   'walk',
#   'wearing',
#   'brown',
#   'black'],
#  ['catwalk', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine', 'products'],
#  ['magnum',
#   'footwear',
#   'lifestyle',
#   'buy',
#   'rs',
#   'flipkart',
#   'com',
#   'genuine'],
#  ['belts',
#   'whether',
#   'way',
#   'work',
#   'travelling',
#   'abroad',
#   'family',
#   'lifestyle',
#   'accessories',
#   'like'],
#  ['rialto', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine', 'products'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine'],
#  ['alfajr', 'youth', 'digital', 'watch', 'men', 'boys', 'buy', 'online', 'rs'],
#  ['la', 'briza', 'ashley', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['tag', 'heuer', 'formula', 'analog', 'watch', 'boys', 'men'],
#  ['boots',
#   'wearing',
#   'pair',
#   'salt',
#   'n',
#   'pepper',
#   'black',
#   'let',
#   'vivacious',
#   'diva'],
#  ['shuz', 'touch', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['wrangler',
#   'skanders',
#   'fit',
#   'men',
#   'jeans',
#   'online',
#   'buy',
#   'brushed',
#   'black',
#   'rs'],
#  ['pair',
#   'steppings',
#   'feel',
#   'top',
#   'world',
#   'boot',
#   'designed',
#   'per',
#   'latest',
#   'trend'],
#  ['boots',
#   'wearing',
#   'pair',
#   'salt',
#   'n',
#   'pepper',
#   'black',
#   'let',
#   'vivacious',
#   'diva'],
#  ['cs', 'costa', 'swiss', 'analog', 'watch', 'boys', 'men', 'buy', 'online'],
#  ['crocs', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine', 'products'],
#  ['breitling', 'flying', 'fish', 'chronograph', 'chronomat', 'model'],
#  ['lyc', 'white', 'casual', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['myra', 'comfortable', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine'],
#  ['style',
#   'watch',
#   'mtg',
#   'brand',
#   'watches',
#   'well',
#   'calibro',
#   'presents',
#   'black',
#   'dial'],
#  ['get', 'glamr', 'designer', 'uggy', 'boots', 'buy', 'ltb', 'u', 'rs'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['rochees', 'analog', 'watch', 'boys', 'buy', 'online', 'rs', 'india'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['greta', 'salt', 'n', 'pepper', 'red', 'boots', 'buy', 'rs'],
#  ['dmf', 'fluid', 'digital', 'watch', 'boys', 'buy', 'online', 'rs'],
#  ['pair',
#   'boots',
#   'steppings',
#   'live',
#   'coloured',
#   'experience',
#   'endless',
#   'comfort',
#   'wearing',
#   'bellies'],
#  ['rialto', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine', 'products'],
#  ['watch',
#   'stylish',
#   'analog',
#   'bombarded',
#   'complimenting',
#   'glances',
#   'walk',
#   'wearing',
#   'black',
#   'coloured'],
#  ['pocket',
#   'jeans',
#   'pair',
#   'contrast',
#   'patch',
#   'belt',
#   'scoop',
#   'detail',
#   'back',
#   'whiskers'],
#  ['steppings', 'trendy', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['disney', 'digital', 'watch', 'boys', 'girls', 'buy', 'online', 'rs'],
#  ['salt', 'n', 'pepper', 'marsha', 'red', 'boots', 'buy'],
#  ['cartier', 'analog', 'watch', 'boys', 'men', 'buy', 'online', 'rs'],
#  ['bruno', 'manetti', 'cannelita', 'boots', 'buy', 'bm', 'jd', 'rs'],
#  ['stylistry', 'maxis', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine'],
#  ['lcs', 'lois', 'caron', 'analog', 'watch', 'boys', 'men', 'buy', 'online'],
#  ['felix', 'analog', 'watch', 'boys', 'men', 'buy', 'online', 'rs'],
#  ['kielz', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['sakay', 'country', 'leather', 'boots', 'buy', 'sak', 'rs', 'flipkart'],
#  ['attractive',
#   'look',
#   'great',
#   'finish',
#   'durability',
#   'la',
#   'briza',
#   'black',
#   'boots',
#   'price'],
#  ['dmk', 'kool', 'kidz', 'analog', 'watch', 'girls', 'boys', 'buy'],
#  ['franck', 'bella', 'analog', 'watch', 'men', 'boys', 'buy', 'online', 'rs'],
#  ['steppings', 'trendy', 'boots', 'buy', 'ml', 'rs', 'flipkart', 'com'],
#  ['dmk', 'yl', 'kool', 'kidz', 'analog', 'watch', 'girls', 'boys'],
#  ['display',
#   'brand',
#   'warranty',
#   'case',
#   'dial',
#   'strap',
#   'hour',
#   'vizion',
#   'sports',
#   'series'],
#  ['vencer', 'stella', 'digital', 'watch', 'boys', 'buy', 'online', 'rs'],
#  ['mile', 'https', 'www', 'dropbox', 'com', 'jpg'],
#  ['cas', 'w', 'casela', 'basic', 'analog', 'watch', 'boys', 'girls', 'buy'],
#  ['sneha', 'unique', 'boots', 'buy', 'sm', 'rs', 'flipkart', 'com'],
#  ['tc_', 'timer', 'analog', 'watch', 'boys', 'buy', 'online', 'rs'],
#  ['blue',
#   'ne',
#   'regular',
#   'fit',
#   'men',
#   'jeans',
#   'online',
#   'buy',
#   'light',
#   'black'],
#  ['shuz', 'touch', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['colat',
#   'roman',
#   'numerals',
#   'analog',
#   'watch',
#   'men',
#   'boys',
#   'buy',
#   'online'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['belle', 'gambe', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['titan', 'analog', 'watch', 'boys', 'men', 'buy', 'online', 'rs'],
#  ['pair',
#   'selfie',
#   'footwear',
#   'collection',
#   'solid',
#   'grab',
#   'wear',
#   'give',
#   'pep',
#   'look'],
#  ['semonday',
#   'clincher',
#   'boots',
#   'buy',
#   'rs',
#   'flipkart',
#   'com',
#   'genuine',
#   'products'],
#  ['watch',
#   'srushti',
#   'men',
#   'women',
#   'boys',
#   'art',
#   'jewelry',
#   'digital',
#   'girls'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['q', 'analog', 'watch', 'girls', 'boys', 'buy', 'online', 'rs'],
#  ['belle', 'gambe', 'boots', 'buy', 'rs', 'flipkart'],
#  ['escort',
#   'analog',
#   'watch',
#   'men',
#   'flaunt',
#   'mantra',
#   'hit',
#   'streets',
#   'style',
#   'wearing'],
#  ['roxy', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine', 'products'],
#  ['lee', 'men', 'jeans', 'online', 'buy', 'rs', 'india', 'shop', 'apparels'],
#  ['bruno', 'manetti', 'boots', 'buy', 'bm', 'rs', 'flipkart', 'com'],
#  ['estilo', 'analog', 'watch', 'boys', 'men', 'buy', 'online', 'rs'],
#  ['blackled',
#   'jack',
#   'klein',
#   'digital',
#   'watch',
#   'boys',
#   'buy',
#   'online',
#   'rs'],
#  ['iw', 'fk', 'north', 'moon', 'silicone', 'ion', 'digital', 'watch', 'boys'],
#  ['shuz', 'touch', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['foot', 'candy', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['credos', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine', 'products'],
#  ['apple',
#   'shaped',
#   'led',
#   'rich',
#   'club',
#   'digital',
#   'watch',
#   'boys',
#   'girls',
#   'buy'],
#  ['black',
#   'digital',
#   'watch',
#   'skmei',
#   'formal',
#   'analog',
#   'men',
#   'boys',
#   'buy'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['watch', 'men', 'women', 'boys', 'kms', 'digital', 'girls', 'led', 'buy'],
#  ['anand', 'archies', 'boots', 'buy', 'aa', 'rs', 'flipkart', 'com'],
#  ['footwear',
#   'quality',
#   'magnum',
#   'leading',
#   'brand',
#   'women',
#   'supplying',
#   'finest',
#   'export',
#   'genuine'],
#  ['steppings', 'trendy', 'boots', 'buy', 'ml', 'rs', 'flipkart', 'com'],
#  ['swag', 'analog', 'watch', 'boys', 'buy', 'online', 'rs', 'india'],
#  ['bonzer',
#   'women',
#   'stylist',
#   'fashionable',
#   'footwear',
#   'boots',
#   'price',
#   'rs'],
#  ['fit',
#   'roadster',
#   'skinny',
#   'men',
#   'jeans',
#   'online',
#   'buy',
#   'md',
#   'indigo',
#   'rs'],
#  ['selfie', 'black', 'denim', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['pair',
#   'top',
#   'steppings',
#   'boots',
#   'feel',
#   'world',
#   'shoes',
#   'let',
#   'sun',
#   'go'],
#  ['q', 'digital', 'watch', 'boys', 'girls', 'buy', 'online', 'rs'],
#  ['belle', 'gambe', 'winter', 'boots', 'buy', 'rs', 'flipkart'],
#  ['digital',
#   'red',
#   'black',
#   'trendy',
#   'hala',
#   'watch',
#   'boys',
#   'girls',
#   'men',
#   'buy'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine'],
#  ['kielz', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine'],
#  ['franck', 'bella', 'analog', 'watch', 'boys', 'men', 'buy', 'online', 'rs'],
#  ['carlton', 'london', 'boots', 'buy', 'cll', 'rs', 'flipkart', 'com'],
#  ['apl_led_black',
#   'ridas',
#   'apple',
#   'shape',
#   'digital',
#   'watch',
#   'boys',
#   'buy',
#   'online',
#   'rs'],
#  ['shuz', 'touch', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['la', 'briza', 'andria', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['watch',
#   'skmei',
#   'sports',
#   'analog',
#   'digital',
#   'men',
#   'boys',
#   'buy',
#   'online'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['carlton', 'london', 'boots', 'buy', 'cll', 'rs', 'flipkart', 'com'],
#  ['dark',
#   'orange',
#   'digital',
#   'watch',
#   'skmei',
#   'sports',
#   'analog',
#   'men',
#   'boys'],
#  ['urban', 'country', 'ladies', 'boots', 'buy', 'uc', 'rs', 'flipkart'],
#  ['sp', 'ethnic', 'analog', 'watch', 'boys', 'buy', 'online', 'rs', 'india'],
#  ['disney', 'analog', 'watch', 'boys', 'girls', 'buy', 'online', 'rs'],
#  ['get', 'glamr', 'designer', 'yuvu', 'boots', 'buy', 'ltb', 'rs'],
#  ['kielz', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine'],
#  ['belle', 'gambe', 'boots', 'buy', 'rs', 'flipkart'],
#  ['remson', 'india', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine'],
#  ['pair',
#   'boots',
#   'steppings',
#   'live',
#   'coloured',
#   'experience',
#   'endless',
#   'comfort',
#   'wearing',
#   'bellies'],
#  ['jacques', 'farel', 'analog', 'watch', 'boys', 'buy', 'online', 'rs'],
#  ['rialto', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine', 'products'],
#  ['pisa', 'salt', 'n', 'pepper', 'black', 'boots', 'buy', 'rs'],
#  ['oxter',
#   'watch',
#   'dial',
#   'movement',
#   'long',
#   'italia',
#   'men',
#   'presents',
#   'new',
#   'range'],
#  ['klaur', 'melbourne', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine'],
#  ['positif', 'analog', 'watch', 'men', 'boys', 'buy', 'online', 'rs'],
#  ['selfie', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine', 'products'],
#  ['_brn', 'signer', 'analog', 'watch', 'men', 'boys', 'buy', 'online', 'rs'],
#  ['boots',
#   'wearing',
#   'pair',
#   'salt',
#   'n',
#   'pepper',
#   'let',
#   'vivacious',
#   'diva',
#   'get'],
#  ['franck', 'bella', 'analog', 'watch', 'boys', 'men', 'buy', 'online', 'rs'],
#  ['get', 'glamr', 'stylish', 'boots', 'buy', 'lt', 'rs'],
#  ['w', 'metal', 'felix', 'analog', 'watch', 'boys', 'girls', 'buy', 'online'],
#  ['pair',
#   'boots',
#   'steppings',
#   'live',
#   'coloured',
#   'experience',
#   'endless',
#   'comfort',
#   'wearing',
#   'bellies'],
#  ['boots', 'steppings', 'buy', 'rs', 'flipkart', 'com', 'genuine'],
#  ['red',
#   'digital',
#   'watch',
#   'skmei',
#   'sports',
#   'men',
#   'boys',
#   'buy',
#   'online'],
#  ['bhai', 'boots', 'fashionable', 'smart', 'casual', 'women', 'price', 'rs'],
#  ['watch',
#   'function',
#   'sports',
#   'digital',
#   'display',
#   'vizion',
#   'series',
#   'boys'],
#  ['boots', 'steppings', 'buy', 'rs', 'flipkart', 'com', 'genuine'],
#  ['steppings', 'trendy', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['sam',
#   'stefy',
#   'committed',
#   'deliver',
#   'finest',
#   'footwear',
#   'ever',
#   'made',
#   'converting',
#   'designs'],
#  ['boots', 'ten', 'women', 'tan', 'mid', 'length', 'price', 'rs'],
#  ['remson', 'india', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine'],
#  ['get', 'glamr', 'dazzle', 'boots', 'buy', 'lt', 'rs'],
#  ['goldjack',
#   'jack',
#   'klein',
#   'analog',
#   'watch',
#   'boys',
#   'men',
#   'buy',
#   'online',
#   'rs'],
#  ['light',
#   'shaggy',
#   'boot',
#   'slippers',
#   'exude',
#   'personality',
#   'structure',
#   'soft',
#   'fold',
#   'tops'],
#  ['fastrack', 'analog', 'watch', 'men', 'boys', 'buy', 'online', 'rs'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['avon', 'analog', 'watch', 'men', 'boys', 'buy', 'online', 'rs'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['franck', 'bella', 'analog', 'watch', 'men', 'boys', 'buy', 'online', 'rs'],
#  ['catwalk', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine', 'products'],
#  ['rialto', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine', 'products'],
#  ['boot',
#   'leather',
#   'pair',
#   'salt',
#   'n',
#   'pepper',
#   'let',
#   'crazy',
#   'pop',
#   'day'],
#  ['qibla',
#   'compass',
#   'alfajr',
#   'digital',
#   'watch',
#   'men',
#   'boys',
#   'girls',
#   'buy'],
#  ['magnum', 'footwear', 'lifestyle', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['pair',
#   'steppings',
#   'feel',
#   'top',
#   'world',
#   'boot',
#   'designed',
#   'per',
#   'latest',
#   'trend'],
#  ['sale', 'funda', 'analog', 'watch', 'boys', 'men', 'buy', 'online', 'rs'],
#  ['steppings', 'trendy', 'boots', 'buy', 'ml', 'rs', 'flipkart', 'com'],
#  ['couple',
#   'britex',
#   'analog',
#   'watch',
#   'best',
#   'gift',
#   'set',
#   'house',
#   'watches',
#   'made'],
#  ['tsg', 'kelz', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine'],
#  ['blue', 'cur', 'silver', 'analog', 'watch', 'boys', 'men', 'buy'],
#  ['j', 'h', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['disney', 'analog', 'watch', 'boys', 'girls', 'buy', 'online', 'rs'],
#  ['get', 'glamr', 'designer', 'snowra', 'boots', 'buy', 'ltb', 'rs'],
#  ['lenco', 'quazi', 'analog', 'digital', 'watch', 'men', 'boys', 'day', 'buy'],
#  ['pinza', 'black', 'christmas', 'boots', 'buy', 'b', 'rs', 'flipkart'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['salt', 'n', 'pepper', 'rebacca', 'almond', 'boots', 'buy', 'rebecca'],
#  ['chrono',
#   'rockstar',
#   'analog',
#   'watch',
#   'men',
#   'boys',
#   'dial',
#   'buy',
#   'online'],
#  ['disney', 'digital', 'watch', 'boys', 'buy', 'online', 'rs', 'india'],
#  ['pair',
#   'selfie',
#   'footwear',
#   'collection',
#   'solid',
#   'grab',
#   'wear',
#   'give',
#   'pep',
#   'look'],
#  ['display',
#   'brand',
#   'warranty',
#   'case',
#   'dial',
#   'strap',
#   'hour',
#   'vizion',
#   'sports',
#   'series'],
#  ['belle', 'gambe', 'boots', 'buy', 'rs', 'flipkart'],
#  ['yellow',
#   'lp',
#   'disney',
#   'analog',
#   'watch',
#   'boys',
#   'girls',
#   'buy',
#   'online'],
#  ['elantra', 'analog', 'watch', 'boys', 'men', 'buy', 'online', 'rs'],
#  ['boots',
#   'choice',
#   'style',
#   'classic',
#   'cold',
#   'winters',
#   'simply',
#   'feminine',
#   'great',
#   'pretty'],
#  ['marvel', 'digital', 'watch', 'boys', 'girls', 'buy', 'online', 'rs'],
#  ['djh', 'women', 'stylist', 'footwear', 'boots', 'price', 'rs'],
#  ['franck', 'bella', 'analog', 'watch', 'men', 'boys', 'buy', 'online', 'rs'],
#  ['get', 'glamr', 'stylish', 'boots', 'buy', 'lt', 'rs'],
#  ['black',
#   'gold',
#   'digital',
#   'watch',
#   'skmei',
#   'sports',
#   'men',
#   'boys',
#   'women'],
#  ['footwear',
#   'quality',
#   'magnum',
#   'leading',
#   'brand',
#   'women',
#   'supplying',
#   'finest',
#   'export',
#   'genuine'],
#  ['pinza', 'blue', 'cowboy', 'boots', 'buy', 'rs', 'flipkart'],
#  ['magnum', 'footwear', 'lifestyle', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['steppings', 'trendy', 'boots', 'buy', 'ml', 'rs', 'flipkart', 'com'],
#  ['denim',
#   'eleganzza',
#   'watch',
#   'analog',
#   'men',
#   'women',
#   'boys',
#   'girls',
#   'couple',
#   'free'],
#  ['catbird', 'boots', 'buy', 'ab', 'rs', 'flipkart', 'com', 'genuine'],
#  ['bruno', 'manetti', 'boots', 'buy', 'bm', 'rs', 'flipkart', 'com'],
#  ['watch',
#   'bdblue',
#   'lenco',
#   'tango',
#   'analog',
#   'men',
#   'boys',
#   'buy',
#   'online',
#   'rs'],
#  ['get', 'glamr', 'designer', 'kuyal', 'boots', 'buy', 'ltb', 'rs'],
#  ['zoop', 'digital', 'watch', 'boys', 'girls', 'buy', 'online', 'rs'],
#  ['shoppingekart',
#   'rewin',
#   'pack',
#   'digital',
#   'watch',
#   'boys',
#   'girls',
#   'couple'],
#  ['stylistry', 'maxis', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['steppings', 'trendy', 'boots', 'buy', 'xf', 'rs', 'flipkart', 'com'],
#  ['boots', 'dorthea', 'salt', 'n', 'pepper', 'almond', 'buy', 'rs'],
#  ['signer', 'analog', 'watch', 'men', 'boys', 'buy', 'online', 'rs'],
#  ['rialto', 'boots', 'buy', 'rs', 'flipkart', 'com', 'genuine', 'products'],
#  ['swissfire', 'analog', 'watch', 'boys', 'men', 'buy', 'online', 'rs'],
#  ['get', 'glamr', 'designer', 'uggy', 'boots', 'buy', 'ltb', 'u', 'rs'],
#  ['avon', 'analog', 'watch', 'men', 'boys', 'buy', 'online', 'rs'],
#  ['carl', 'cheetablue', 'boots', 'buy', 'cheetah', 'rs', 'flipkart'],
#  ['digi',
#   'yellow',
#   'logues',
#   'sports',
#   'analog',
#   'digital',
#   'watch',
#   'boys',
#   'buy'],
#  ['kielz', 'ladies', 'boots', 'buy', 'rs', 'flipkart', 'com'],
#  ['swag', 'analog', 'watch', 'boys', 'buy', 'online', 'rs', 'india'],
#  ['zoop', 'analog', 'watch', 'boys', 'girls', 'buy', 'online', 'rs'],
#  ['brown', 'shiver', 'timbers', 'boots', 'buy', 'rs', 'flipkart'],
#  ['cm', 'golf', 'ball', 'ezyprnt', 'size', 'diameter', 'rh'],
#  ['ball', 'size', 'diameter', 'cm', 'pack', 'package', 'ezyprnt'],
#  ['cm', 'golf', 'ball', 'ezyprnt', 'size', 'diameter', 'ol'],
#  ['ball', 'size', 'diameter', 'cm', 'pack', 'package', 'ezyprnt'],
#  ['printed',
#   'protective',
#   'men',
#   'gloves',
#   'traditions',
#   'cotton',
#   'brand',
#   'color',
#   'red',
#   'black'],
#  ['diwan',
#   'cm',
#   'inch',
#   'first',
#   'choice',
#   'cotton',
#   'embroidered',
#   'sheet',
#   'cushion',
#   'cover'],
#  ['cap', 'eccellente', 'solid', 'hip', 'hop', 'cotton', 'brand', 'known'],
#  ['magnetic',
#   'whiteboard',
#   'resin',
#   'melamine',
#   'small',
#   'whiteboards',
#   'white',
#   'green',
#   'framed',
#   'mm'],
#  ['printed',
#   'protective',
#   'men',
#   'gloves',
#   'traditions',
#   'cotton',
#   'brand',
#   'color',
#   'black',
#   'glove'],
#  ['diwan',
#   'cm',
#   'inch',
#   'first',
#   'choice',
#   'cotton',
#   'embroidered',
#   'sheet',
#   'cushion',
#   'cover'],
#  ['diwan',
#   'cm',
#   'inch',
#   'first',
#   'choice',
#   'cotton',
#   'embroidered',
#   'sheet',
#   'cushion',
#   'cover'],
#  ['skates',
#   'senior',
#   'bag',
#   'superior',
#   'helmet',
#   'knee',
#   'elbow',
#   'suitable',
#   'skating',
#   'product'],
#  ['dress',
#   'layered',
#   'masaba',
#   'magic',
#   'fairy',
#   'girl',
#   'pink',
#   'pretty',
#   'neck'],
#  ['abaya',
#   'kashibo',
#   'blue',
#   'momin',
#   'libas',
#   'solid',
#   'dress',
#   'length',
#   'cm'],
#  ['item',
#   'pouch',
#   'cover',
#   'acm',
#   'swipe',
#   'elite',
#   'plus',
#   'black',
#   'leather',
#   'screen'],
#  ['musical',
#   'cow',
#   'r',
#   'enterprises',
#   'wlking',
#   'age',
#   'instruments',
#   'min',
#   'yrs'],
#  ['diwan',
#   'cm',
#   'inch',
#   'first',
#   'choice',
#   'cotton',
#   'embroidered',
#   'sheet',
#   'cushion',
#   'cover'],
#  ['diwan',
#   'cm',
#   'inch',
#   'santosh',
#   'royal',
#   'fashion',
#   'cotton',
#   'embroidered',
#   'sheet',
#   'cushion'],
#  ['diwan',
#   'cm',
#   'inch',
#   'first',
#   'choice',
#   'cotton',
#   'embroidered',
#   'sheet',
#   'cushion',
#   'cover'],
#  ['shoebuzz',
#   'casuals',
#   'material',
#   'synthetic',
#   'casual',
#   'leather',
#   'occasion',
#   'wedding',
#   'party',
#   'color'],
#  ['zed',
#   'loafers',
#   'material',
#   'occasion',
#   'casual',
#   'color',
#   'grey',
#   'heel',
#   'height'],
#  ['cotton', 'duvet', 'cover', 'house', 'queen', 'grey', 'material', 'code'],
#  ['item',
#   'pouch',
#   'cover',
#   'acm',
#   'intex',
#   'aqua',
#   'lions',
#   'purple',
#   'leather'],
#  ['na',
#   'diamond',
#   'bracelet',
#   'gold',
#   'womaniya',
#   'alloy',
#   'free',
#   'ideal',
#   'girls',
#   'women'],
#  ['na',
#   'pearl',
#   'diamond',
#   'taj',
#   'alloy',
#   'cuff',
#   'free',
#   'size',
#   'gold',
#   'ideal'],
#  ['cm',
#   'shoe',
#   'combo',
#   'skating',
#   'product',
#   'jaspo',
#   'saphire',
#   'dual',
#   'skates',
#   'size'],
#  ['na',
#   'pearl',
#   'diamond',
#   'taj',
#   'alloy',
#   'cuff',
#   'free',
#   'size',
#   'gold',
#   'ideal'],
#  ['musical', 'teddy', 'bear', 'bento', 'age', 'stuff', 'toys', 'min', 'yrs'],
#  ['sweatshirt',
#   'sleeve',
#   'wake',
#   'competition',
#   'full',
#   'striped',
#   'men',
#   'pockets',
#   'wash',
#   'hooded'],
#  ['na',
#   'pearl',
#   'diamond',
#   'taj',
#   'alloy',
#   'cuff',
#   'free',
#   'size',
#   'gold',
#   'ideal'],
#  ['na',
#   'pearl',
#   'diamond',
#   'taj',
#   'alloy',
#   'cuff',
#   'free',
#   'size',
#   'gold',
#   'ideal'],
#  ['warranty',
#   'lcd',
#   'product',
#   'condition',
#   'screen',
#   'technician',
#   'cellbazaar',
#   'blackberry',
#   'white'],
#  ['gold',
#   'clutch',
#   'synthetic',
#   'dressberry',
#   'one',
#   'style',
#   'code',
#   'price',
#   'rs'],
#  ['black',
#   'clutch',
#   'mast',
#   'harbour',
#   'synthetic',
#   'one',
#   'style',
#   'code',
#   'price',
#   'rs'],
#  ['jqr',
#   'shoes',
#   'sports',
#   'running',
#   'material',
#   'sole',
#   'occasion',
#   'phylon',
#   'latest'],
#  ['stole',
#   'poly',
#   'cotton',
#   'sisel',
#   'printed',
#   'women',
#   'brand',
#   'style',
#   'color',
#   'peach'],
#  ['jqr',
#   'shoes',
#   'sports',
#   'running',
#   'material',
#   'sole',
#   'occasion',
#   'phylon',
#   'latest',
#   'range'],
#  ['shoes',
#   'sports',
#   'running',
#   'walking',
#   'material',
#   'knight',
#   'ace',
#   'kraasa',
#   'cycling',
#   'synthetic'],
#  ['gold',
#   'clutch',
#   'dressberry',
#   'synthetic',
#   'one',
#   'style',
#   'code',
#   'price',
#   'rs'],
#  ['wool', 'stole', 'floral', 'yarn', 'kashmiri', 'ruffle', 'print', 'viscose'],
#  ['stole',
#   'viscose',
#   'women',
#   'indistar',
#   'self',
#   'design',
#   'scarf',
#   'stoles',
#   'brand',
#   'color'],
#  ['black',
#   'clutch',
#   'synthetic',
#   'mast',
#   'harbour',
#   'one',
#   'code',
#   'price',
#   'rs'],
#  ['shoes',
#   'sports',
#   'material',
#   'glacier',
#   'running',
#   'occasion',
#   'ideal',
#   'men',
#   'shoe'],
#  ['black',
#   'clutch',
#   'synthetic',
#   'dressberry',
#   'one',
#   'style',
#   'code',
#   'price',
#   'rs'],
#  ['clutch',
#   'blue',
#   'heavy',
#   'duty',
#   'satin',
#   'wong',
#   'mm',
#   'zoe',
#   'marciano',
#   'handle'],
#  ['gel',
#   'cumulus',
#   'asics',
#   'shoes',
#   'running',
#   'cushioning',
#   'gait',
#   'guidance',
#   'seamless'],
#  ['black',
#   'clutch',
#   'synthetic',
#   'dressberry',
#   'one',
#   'style',
#   'code',
#   'price',
#   'rs'],
#  ['gold',
#   'clutch',
#   'synthetic',
#   'mast',
#   'harbour',
#   'one',
#   'code',
#   'price',
#   'rs'],
#  ['gel',
#   'heel',
#   'asics',
#   'kayano',
#   'shoes',
#   'system',
#   'running',
#   'material',
#   'comfort'],
#  ['stole',
#   'viscose',
#   'women',
#   'indistar',
#   'self',
#   'design',
#   'scarf',
#   'casual',
#   'stoles'],
#  ['clutch',
#   'orange',
#   'synthetic',
#   'dressberry',
#   'one',
#   'style',
#   'code',
#   'price',
#   'rs'],
#  ['gold',
#   'clutch',
#   'synthetic',
#   'dressberry',
#   'one',
#   'style',
#   'code',
#   'price',
#   'rs'],
#  ['green',
#   'clutch',
#   'dressberry',
#   'synthetic',
#   'one',
#   'style',
#   'code',
#   'price',
#   'rs'],
#  ['clutch',
#   'blue',
#   'heavy',
#   'duty',
#   'satin',
#   'wong',
#   'zoe',
#   'marciano',
#   'mm',
#   'long'],
#  ['escan',
#   'lace',
#   'quality',
#   'stylish',
#   'material',
#   'genuine',
#   'highly',
#   'durable',
#   'fashionable',
#   'finest'],
#  ['gold',
#   'clutch',
#   'dressberry',
#   'synthetic',
#   'one',
#   'style',
#   'code',
#   'price',
#   'rs'],
#  ['fit',
#   'flare',
#   'women',
#   'dress',
#   'nine',
#   'maternity',
#   'wear',
#   'multicolor',
#   'dimensions',
#   'length'],
#  ['party',
#   'festive',
#   'casual',
#   'blue',
#   'pu',
#   'clutch',
#   'mm',
#   'kleio',
#   'occasion'],
#  ['cm',
#   'skipper',
#   'blends',
#   'aqua',
#   'eyelet',
#   'window',
#   'curtain',
#   'striped',
#   'height'],
#  ['fit',
#   'solid',
#   'men',
#   'wind',
#   'cheater',
#   'dynamotion',
#   'mizuno',
#   'lightweight',
#   'hoody',
#   'pattern'],
#  ['gloves',
#   'batting',
#   'fingers',
#   'men',
#   'white',
#   'orange',
#   'hand',
#   'yes',
#   'design',
#   'flex'],
#  ['gloves',
#   'batting',
#   'turbo',
#   'men',
#   'white',
#   'blue',
#   'league',
#   'right',
#   'cricket',
#   'design'],
#  ['g',
#   'information',
#   'stamin',
#   'mass',
#   'gainers',
#   'kg',
#   'strawberry',
#   'protein',
#   'workout'],
#  ['pure',
#   'source',
#   'psi',
#   'hanggnrlx',
#   'relaxing',
#   'liquid',
#   'air',
#   'freshener',
#   'buy',
#   'rs'],
#  ['grey',
#   'colour',
#   'formal',
#   'women',
#   'top',
#   'viscose',
#   'elegant',
#   'adds',
#   'feminine',
#   'charm'],
#  ['svt', 'ada', 'collections', 'party', 'sleeve', 'checkered', 'women', 'top'],
#  ['elegant',
#   'svt',
#   'women',
#   'top',
#   'unique',
#   'winter',
#   'collection',
#   'house',
#   'yet',
#   'stylish'],
#  ['asian',
#   'gems',
#   'jewels',
#   'dhaatu',
#   'metal',
#   'alloy',
#   'opal',
#   'ring',
#   'buy'],
#  ['asian',
#   'gems',
#   'jewels',
#   'dhaatu',
#   'metal',
#   'alloy',
#   'opal',
#   'ring',
#   'buy'],
#  ['asian',
#   'gems',
#   'jewels',
#   'dhaatu',
#   'metal',
#   'alloy',
#   'amethyst',
#   'ring',
#   'buy'],
#  ['curtains',
#   'kings',
#   'tassels',
#   'deal',
#   'presents',
#   'choose',
#   'wide',
#   'range',
#   'choices',
#   'make'],
#  ['diamond', 'gold', 'ring', 'avsar', 'sachi', 'real', 'kt', 'wt'],
#  ['peppermint',
#   'blues',
#   'casual',
#   'sleeveless',
#   'printed',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'black'],
#  ['nishtaa',
#   'jewellery',
#   'rings',
#   'light',
#   'weight',
#   'products',
#   'gold',
#   'ring',
#   'presents',
#   'stunning'],
#  ['xpert',
#   'schoolboys',
#   'blk',
#   'lace',
#   'shoes',
#   'buy',
#   'schoolboysshoes',
#   'rs',
#   'flipkart'],
#  ['time', 'fashions', 'women', 'line', 'dress', 'online', 'buy', 'red', 'rs'],
#  ['dress',
#   'add',
#   'look',
#   'yepme',
#   'beautifully',
#   'designed',
#   'ready',
#   'extra',
#   'charm',
#   'made'],
#  ['van',
#   'heusen',
#   'men',
#   'printed',
#   'party',
#   'shirt',
#   'online',
#   'buy',
#   'black',
#   'rs'],
#  ['laughing',
#   'buddha',
#   'main',
#   'door',
#   'wealth',
#   'auspicious',
#   'location',
#   'facing',
#   'keep',
#   'table'],
#  ['ring',
#   'promise',
#   'diamonds',
#   'ethnic',
#   'design',
#   'recreated',
#   'split',
#   'shoulder',
#   'superior',
#   'finish'],
#  ['nishtaa', 'yellow', 'gold', 'k', 'ring', 'buy', 'rs', 'flipkart'],
#  ['dress',
#   'blue',
#   'lace',
#   'straight',
#   'mykraft',
#   'girl',
#   'line',
#   'price',
#   'rs'],
#  ['cranberry',
#   'club',
#   'girl',
#   'gathered',
#   'dress',
#   'online',
#   'buy',
#   'orange',
#   'rs'],
#  ['fashion',
#   'tree',
#   'men',
#   'solid',
#   'formal',
#   'shirt',
#   'online',
#   'buy',
#   'red',
#   'rs'],
#  ['fashion',
#   'tree',
#   'men',
#   'solid',
#   'formal',
#   'shirt',
#   'online',
#   'buy',
#   'dark',
#   'blue'],
#  ['fashion',
#   'tree',
#   'men',
#   'solid',
#   'formal',
#   'shirt',
#   'online',
#   'buy',
#   'purple',
#   'rs'],
#  ['peter',
#   'england',
#   'men',
#   'solid',
#   'formal',
#   'shirt',
#   'online',
#   'buy',
#   'green',
#   'rs'],
#  ['gee',
#   'bee',
#   'presents',
#   'cotton',
#   'womens',
#   'kurtis',
#   'premium',
#   'qality',
#   'ozone'],
#  ['gee',
#   'bee',
#   'presents',
#   'cotton',
#   'womens',
#   'kurtis',
#   'premium',
#   'qality',
#   'ozone'],
#  ['com',
#   'dumdaar',
#   'casual',
#   'short',
#   'sleeve',
#   'self',
#   'design',
#   'women',
#   'top',
#   'online'],
#  ['sleeve',
#   'style',
#   'designed',
#   'crochet',
#   'cotton',
#   'lace',
#   'neck',
#   'elasticated',
#   'smocked',
#   'waist'],
#  ['oviya',
#   'casual',
#   'sleeveless',
#   'self',
#   'design',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'blue'],
#  ['clove', 'casual', 'sleeve', 'self', 'design', 'women', 'top', 'online'],
#  ['full',
#   'top',
#   'casual',
#   'tie',
#   'neck',
#   'elasticated',
#   'bottom',
#   'teal',
#   'color',
#   'sleeves'],
#  ['top',
#   'double',
#   'fashion',
#   'flair',
#   'wearing',
#   'designed',
#   'per',
#   'latest',
#   'trends',
#   'fashioned'],
#  ['fantasy', 'ika', 'casual', 'sleeve', 'self', 'design', 'women', 'top'],
#  ['ausy',
#   'casual',
#   'short',
#   'sleeve',
#   'floral',
#   'print',
#   'women',
#   'top',
#   'online',
#   'buy'],
#  ['ausy',
#   'casual',
#   'short',
#   'sleeve',
#   'printed',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'black'],
#  ['ring',
#   'promise',
#   'diamonds',
#   'ethnic',
#   'design',
#   'recreated',
#   'split',
#   'shoulder',
#   'superior',
#   'finish'],
#  ['pieces',
#   'wearyourshine',
#   'please',
#   'note',
#   'diamonds',
#   'clarity',
#   'vssi',
#   'color',
#   'jk',
#   'pc'],
#  ['black',
#   'short',
#   'printed',
#   'top',
#   'round',
#   'neck',
#   'sleeves',
#   'sweet',
#   'heart',
#   'cut'],
#  ['top',
#   'blue',
#   'emblished',
#   'side',
#   'seamless',
#   'triangle',
#   'patch',
#   'net',
#   'v',
#   'neck'],
#  ['printed',
#   'top',
#   'green',
#   'knitted',
#   'round',
#   'neck',
#   'dropped',
#   'shoulder',
#   'sleeves',
#   'drawsting'],
#  ['sleeve',
#   'printed',
#   'top',
#   'light',
#   'brown',
#   'round',
#   'neck',
#   'button',
#   'loop',
#   'closure'],
#  ['back',
#   'printed',
#   'top',
#   'white',
#   'coloured',
#   'lace',
#   'accents',
#   'round',
#   'neck',
#   'bow'],
#  ['top',
#   'turquoise',
#   'blue',
#   'woven',
#   'round',
#   'neck',
#   'flap',
#   'laser',
#   'cut',
#   'curved'],
#  ['short',
#   'printed',
#   'top',
#   'blue',
#   'round',
#   'neck',
#   'sleeves',
#   'sweet',
#   'heart',
#   'cut'],
#  ['neck',
#   'back',
#   'printed',
#   'top',
#   'multicoloured',
#   'halter',
#   'v',
#   'line',
#   'hole',
#   'detail'],
#  ['back',
#   'printed',
#   'top',
#   'multicoloured',
#   'lace',
#   'accents',
#   'round',
#   'neck',
#   'bow',
#   'design'],
#  ['back',
#   'printed',
#   'top',
#   'brown',
#   'coloured',
#   'lace',
#   'accents',
#   'round',
#   'neck',
#   'bow'],
#  ['sleeve',
#   'printed',
#   'top',
#   'cream',
#   'floral',
#   'round',
#   'neck',
#   'button',
#   'loop',
#   'closure'],
#  ['top',
#   'green',
#   'round',
#   'neck',
#   'pink',
#   'lace',
#   'panel',
#   'front',
#   'back',
#   'shilpkala'],
#  ['sleeveless',
#   'printed',
#   'top',
#   'multicoloured',
#   'round',
#   'neck',
#   'pointed',
#   'hem',
#   'shilpkala',
#   'casual'],
#  ['shilpkala',
#   'top',
#   'mauve',
#   'wrinkled',
#   'crop',
#   'round',
#   'neck',
#   'curved',
#   'hem',
#   'back'],
#  ['bluestone',
#   'juliette',
#   'yellow',
#   'gold',
#   'diamond',
#   'k',
#   'ring',
#   'buy',
#   'rs'],
#  ['om',
#   'ring',
#   'power',
#   'karatcraft',
#   'diamond',
#   'religious',
#   'unisex',
#   'wear',
#   'positivity',
#   'custom'],
#  ['diamond',
#   'ring',
#   'gold',
#   'affordable',
#   'design',
#   'everyday',
#   'use',
#   'office',
#   'never',
#   'want'],
#  ['top',
#   'neck',
#   'casual',
#   'party',
#   'round',
#   'lether',
#   'like',
#   'around',
#   'shoulder',
#   'makes'],
#  ['aaliya',
#   'casual',
#   'sleeveless',
#   'embellished',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'black',
#   'rs'],
#  ['karatcraft',
#   'robini',
#   'emerald',
#   'gold',
#   'diamond',
#   'k',
#   'ring',
#   'buy',
#   'rs'],
#  ['casual',
#   'festive',
#   'formal',
#   'lounge',
#   'wear',
#   'party',
#   'sleeveless',
#   'embellished',
#   'women'],
#  ['om',
#   'ring',
#   'power',
#   'karatcraft',
#   'diamond',
#   'religious',
#   'unisex',
#   'wear',
#   'positivity',
#   'custom'],
#  ['piece',
#   'look',
#   'lee',
#   'mark',
#   'shirt',
#   'brand',
#   'casual',
#   'shirts',
#   'fashion',
#   'essential'],
#  ['kairaa',
#   'lounge',
#   'wear',
#   'sleeveless',
#   'embellished',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'black'],
#  ['side',
#   'soie',
#   'top',
#   'get',
#   'hands',
#   'trendy',
#   'yet',
#   'comfortable',
#   'made',
#   'keeping'],
#  ['hichkii',
#   'casual',
#   'cape',
#   'sleeve',
#   'embroidered',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'white'],
#  ['top',
#   'casual',
#   'modal',
#   'wide',
#   'shoulder',
#   'straps',
#   'comes',
#   'two',
#   'colour',
#   'tones'],
#  ['silver',
#   'ring',
#   'bis',
#   'hallmarked',
#   'gemstone',
#   'certified',
#   'artistically',
#   'made',
#   'according'],
#  ['silver',
#   'ring',
#   'bis',
#   'hallmarked',
#   'gemstone',
#   'certified',
#   'artistically',
#   'made',
#   'according'],
#  ['silver',
#   'ring',
#   'bis',
#   'hallmarked',
#   'gemstone',
#   'certified',
#   'artistically',
#   'made',
#   'according'],
#  ['species',
#   'striped',
#   'round',
#   'neck',
#   'women',
#   'sweater',
#   'online',
#   'buy',
#   'white',
#   'rs'],
#  ['silver',
#   'ring',
#   'bis',
#   'hallmarked',
#   'gemstone',
#   'certified',
#   'artistically',
#   'made',
#   'according'],
#  ['silver',
#   'ring',
#   'bis',
#   'hallmarked',
#   'gemstone',
#   'certified',
#   'artistically',
#   'made'],
#  ['silver',
#   'ring',
#   'bis',
#   'hallmarked',
#   'gemstone',
#   'certified',
#   'artistically',
#   'made'],
#  ['bluestone', 'princess', 'gold', 'diamond', 'k', 'ring', 'buy', 'rs'],
#  ['varanga',
#   'casual',
#   'short',
#   'sleeve',
#   'printed',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'black'],
#  ['varanga',
#   'casual',
#   'short',
#   'sleeve',
#   'printed',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'white'],
#  ['orous', 'casual', 'sleeve', 'printed', 'women', 'top', 'online', 'buy'],
#  ['set',
#   'wedding',
#   'lingerie',
#   'product',
#   'fit',
#   'wardrobe',
#   'good',
#   'combination',
#   'comfort',
#   'fashion'],
#  ['nishtaa', 'yellow', 'gold', 'cubic', 'zirconia', 'k', 'ring', 'buy', 'rs'],
#  ['anti',
#   'dress',
#   'beautiful',
#   'lace',
#   'jaune',
#   'model',
#   'choice',
#   'get',
#   'bold',
#   'blue'],
#  ['living',
#   'world',
#   'home',
#   'stop',
#   'solid',
#   'wood',
#   'display',
#   'unit',
#   'buy',
#   'rs'],
#  ['status',
#   'quo',
#   'men',
#   'solid',
#   'casual',
#   'shirt',
#   'online',
#   'buy',
#   'navy',
#   'rs'],
#  ['planet',
#   'connect',
#   'considered',
#   'enhance',
#   'empower',
#   'earth',
#   'planets',
#   'metals'],
#  ['asian',
#   'gems',
#   'jewels',
#   'dhaatu',
#   'metal',
#   'alloy',
#   'zircon',
#   'ring',
#   'buy'],
#  ['inch',
#   'casual',
#   'size',
#   'l',
#   'chest',
#   'length',
#   'short',
#   'sleeves',
#   'attached'],
#  ['inch', 'size', 'free', 'chest', 'stachable', 'solder', 'length'],
#  ['make',
#   'summer',
#   'tops',
#   'embellish',
#   'crowd',
#   'everyone',
#   'jealous',
#   'prettypataka',
#   'party',
#   'full'],
#  ['inch', 'sleeveless', 'top', 'size', 'free', 'chest', 'length'],
#  ['tenn',
#   'casual',
#   'party',
#   'sleeveless',
#   'floral',
#   'print',
#   'women',
#   'top',
#   'online',
#   'buy'],
#  ['top',
#   'colored',
#   'look',
#   'wear',
#   'maggie',
#   'party',
#   'sleeveless',
#   'floral',
#   'add',
#   'white'],
#  ['retaaz',
#   'casual',
#   'party',
#   'festive',
#   'sleeveless',
#   'floral',
#   'print',
#   'women',
#   'top',
#   'online'],
#  ['retaaz',
#   'casual',
#   'party',
#   'festive',
#   'sleeveless',
#   'floral',
#   'print',
#   'women',
#   'top',
#   'online'],
#  ['shoes',
#   'men',
#   'sports',
#   'offer',
#   'best',
#   'comfort',
#   'synthetic',
#   'leather',
#   'upper',
#   'mesh'],
#  ['urban',
#   'fashion',
#   'bank',
#   'casual',
#   'party',
#   'festive',
#   'lounge',
#   'wear',
#   'sleeveless',
#   'embellished'],
#  ['top',
#   'black',
#   'plain',
#   'attached',
#   'white',
#   'inner',
#   'spies',
#   'adding',
#   'style',
#   'wear'],
#  ['urban',
#   'fashion',
#   'bank',
#   'casual',
#   'party',
#   'festive',
#   'lounge',
#   'wear',
#   'sleeveless',
#   'printed'],
#  ['urban', 'fashion', 'bank', 'casual', 'sleeve', 'solid', 'women', 'top'],
#  ['hangover',
#   'solid',
#   'round',
#   'neck',
#   'women',
#   'sweater',
#   'online',
#   'buy',
#   'cloudy',
#   'sky'],
#  ['elson',
#   'self',
#   'design',
#   'v',
#   'neck',
#   'women',
#   'sweater',
#   'online',
#   'buy',
#   'yellow'],
#  ['pieces',
#   'wearyourshine',
#   'pc',
#   'jeweller',
#   'expert',
#   'curation',
#   'fine',
#   'jewellery',
#   'expressive',
#   'women'],
#  ['planet',
#   'connect',
#   'considered',
#   'enhance',
#   'empower',
#   'earth',
#   'planets',
#   'metals'],
#  ['chest',
#   'striped',
#   'top',
#   'stylish',
#   'v',
#   'neck',
#   'button',
#   'design',
#   'size'],
#  ['teemoods',
#   'casual',
#   'full',
#   'sleeve',
#   'striped',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'blue'],
#  ['colbrii',
#   'casual',
#   'full',
#   'sleeve',
#   'printed',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'blue'],
#  ['ring',
#   'witty',
#   'ravishing',
#   'topaz',
#   'white',
#   'gold',
#   'yet',
#   'elegantly',
#   'simple',
#   'yellow'],
#  ['addiction',
#   'full',
#   'top',
#   'womens',
#   'sleeves',
#   'emb',
#   'casual',
#   'sleeve',
#   'embroidered',
#   'women'],
#  ['full',
#   'sleeve',
#   'women',
#   'top',
#   'blue',
#   'poly',
#   'sfds',
#   'casual',
#   'formal',
#   'party'],
#  ['membooz',
#   'looking',
#   'trend',
#   'setter',
#   'go',
#   'fanciest',
#   'parties',
#   'weekend',
#   'range',
#   'apparel'],
#  ['full',
#   'design',
#   'top',
#   'slim',
#   'fit',
#   'thread',
#   'seroski',
#   'work',
#   'sleeves',
#   'woollen'],
#  ['ring',
#   'diamonds',
#   'gold',
#   'design',
#   'inspired',
#   'love',
#   'crafted',
#   'close',
#   'setting'],
#  ['diamond',
#   'ring',
#   'like',
#   'set',
#   'look',
#   'solitaire',
#   'solitana',
#   'designer',
#   'marvel',
#   'connoisseur'],
#  ['solitaire',
#   'design',
#   'clariz',
#   'ring',
#   'small',
#   'cathedral',
#   'designed',
#   'enhance',
#   'centre',
#   'piece'],
#  ['herberto', 'girl', 'line', 'dress', 'online', 'buy', 'blue', 'rs', 'india'],
#  ['diamond',
#   'ring',
#   'like',
#   'solitana',
#   'set',
#   'look',
#   'solitaire',
#   'designer',
#   'marvel',
#   'connoisseur'],
#  ['diamond',
#   'ring',
#   'like',
#   'set',
#   'look',
#   'solitaire',
#   'solitana',
#   'designer',
#   'marvel',
#   'connoisseur'],
#  ['dress',
#   'girl',
#   'ready',
#   'celebrate',
#   'weather',
#   'blue',
#   'color',
#   'butterfly',
#   'print',
#   'kob'],
#  ['dress',
#   'abhira',
#   'give',
#   'trendy',
#   'bright',
#   'look',
#   'daughter',
#   'buying',
#   'made',
#   'lycra'],
#  ['herberto', 'girl', 'high', 'low', 'dress', 'online', 'buy', 'maroon', 'rs'],
#  ['herberto', 'girl', 'line', 'dress', 'online', 'buy', 'grey', 'rs', 'india'],
#  ['nighty',
#   'fasense',
#   'women',
#   'short',
#   'exclusive',
#   'purple',
#   'multicolor',
#   'nightwear',
#   'size'],
#  ['megha',
#   'casual',
#   'short',
#   'sleeve',
#   'printed',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'blue'],
#  ['diamond',
#   'ring',
#   'rubies',
#   'cocktail',
#   'enchantress',
#   'ask',
#   'stone',
#   'choice',
#   'emerald',
#   'sapphire'],
#  ['diamond',
#   'ring',
#   'like',
#   'set',
#   'look',
#   'solitaire',
#   'solitana',
#   'designer',
#   'marvel',
#   'connoisseur'],
#  ['caratlane',
#   'fantasia',
#   'band',
#   'white',
#   'gold',
#   'diamond',
#   'k',
#   'ring',
#   'buy'],
#  ['various',
#   'aadivasi',
#   'group',
#   'making',
#   'artefact',
#   'karigaari',
#   'merry',
#   'iron',
#   'indian',
#   'society'],
#  ['pieces',
#   'wearyourshine',
#   'please',
#   'note',
#   'diamonds',
#   'clarity',
#   'vssi',
#   'color',
#   'jk',
#   'pc'],
#  ['sfds',
#   'casual',
#   'formal',
#   'party',
#   'short',
#   'sleeve',
#   'self',
#   'design',
#   'women',
#   'top'],
#  ['top',
#   'sfds',
#   'double',
#   'fashion',
#   'flair',
#   'wear',
#   'house',
#   'made',
#   'premium',
#   'quality'],
#  ['top',
#   'sfds',
#   'double',
#   'fashion',
#   'flair',
#   'wear',
#   'house',
#   'made',
#   'premium',
#   'quality'],
#  ['top',
#   'sfds',
#   'double',
#   'fashion',
#   'flair',
#   'wear',
#   'house',
#   'made',
#   'premium',
#   'quality'],
#  ['top',
#   'sfds',
#   'double',
#   'fashion',
#   'flair',
#   'wear',
#   'house',
#   'made',
#   'premium',
#   'quality'],
#  ['nishtaa',
#   'jewellery',
#   'rings',
#   'light',
#   'weight',
#   'products',
#   'gold',
#   'ring',
#   'presents',
#   'stunning'],
#  ['top',
#   'sfds',
#   'double',
#   'fashion',
#   'flair',
#   'wear',
#   'house',
#   'made',
#   'premium',
#   'quality'],
#  ['top',
#   'sfds',
#   'double',
#   'fashion',
#   'flair',
#   'wear',
#   'house',
#   'made',
#   'premium',
#   'quality'],
#  ['scratches',
#   'sony',
#   'xperia',
#   'dual',
#   'imported',
#   'eco',
#   'friendly',
#   'hybrid',
#   'material'],
#  ['piece',
#   'look',
#   'lee',
#   'mark',
#   'shirt',
#   'brand',
#   'casual',
#   'shirts',
#   'fashion',
#   'essential'],
#  ['kalakruti',
#   'k',
#   'jewellery',
#   'b',
#   'jewelry',
#   'box',
#   'makeup',
#   'vanity',
#   'multi',
#   'purpose'],
#  ['karatcraft', 'trilic', 'gold', 'diamond', 'k', 'ring', 'buy', 'rs'],
#  ['diamond',
#   'ring',
#   'like',
#   'set',
#   'look',
#   'solitaire',
#   'solitana',
#   'designer',
#   'marvel',
#   'connoisseur'],
# ...
#   'brown',
#   'aroma',
#   'burner',
#   'combo',
#   'lemongrass',
#   'liquid',
#   'air',
#   'freshener',
#   'buy'],
#  ['fragrance',
#   'aroma',
#   'burner',
#   'room',
#   'home',
#   'combo',
#   'unique',
#   'tea',
#   'oil',
#   'surface'],
#  ['myesquire',
#   'ceramic',
#   'burner',
#   'pot',
#   'lemongrass',
#   'liquid',
#   'air',
#   'freshener',
#   'buy',
#   'rs'],
#  ['bluestone',
#   'golden',
#   'arm',
#   'yellow',
#   'gold',
#   'diamond',
#   'pearl',
#   'k',
#   'ring'],
#  ['league', 'girl', 'gathered', 'dress', 'online', 'buy', 'royal', 'rs'],
#  ['league', 'girl', 'gathered', 'dress', 'online', 'buy', 'yellow', 'rs'],
#  ['league', 'girl', 'gathered', 'dress', 'online', 'buy', 'white', 'rs'],
#  ['league', 'girl', 'gathered', 'dress', 'online', 'buy', 'pink', 'rs'],
#  ['cation',
#   'casual',
#   'short',
#   'sleeve',
#   'solid',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'red'],
#  ['blacksoul',
#   'casual',
#   'short',
#   'sleeve',
#   'solid',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'cranberry'],
#  ['jewlook', 'neck', 'tie', 'men', 'combo', 'online', 'buy', 'rs', 'india'],
#  ['palette',
#   'casual',
#   'sleeveless',
#   'solid',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'purple',
#   'rs'],
#  ['look',
#   'top',
#   'day',
#   'strike',
#   'glamour',
#   'flattering',
#   'tank',
#   'amazingly',
#   'comfortable',
#   'made'],
#  ['look',
#   'top',
#   'day',
#   'strike',
#   'glamour',
#   'flattering',
#   'tank',
#   'amazingly',
#   'comfortable',
#   'made'],
#  ['top', 'yellow', 'color', 'cotton', 'swiss', 'dot', 'sleeves', 'vanca'],
#  ['casual',
#   'top',
#   'fuchsia',
#   'color',
#   'overlapping',
#   'smoking',
#   'detail',
#   'sleeves'],
#  ['contrast',
#   'white',
#   'dry',
#   'komnil',
#   'polo',
#   'premium',
#   'quality',
#   'pique',
#   'knit',
#   'full'],
#  ['kaaryah',
#   'formal',
#   'short',
#   'sleeve',
#   'solid',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'white'],
#  ['kaaryah',
#   'formal',
#   'sleeveless',
#   'solid',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'white',
#   'rs'],
#  ['h',
#   'e',
#   'creations',
#   'brass',
#   'cubic',
#   'zirconia',
#   'yellow',
#   'gold',
#   'ring',
#   'buy'],
#  ['sleeve',
#   'light',
#   'weight',
#   'natural',
#   'viscose',
#   'arrow',
#   'shaped',
#   'hand',
#   'embroidery',
#   'wear'],
#  ['top',
#   'sleeve',
#   'pleated',
#   'front',
#   'box',
#   'pleat',
#   'add',
#   'round',
#   'neck',
#   'structured'],
#  ['schwof',
#   'casual',
#   'full',
#   'sleeve',
#   'solid',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'black'],
#  ['schwof',
#   'party',
#   'full',
#   'sleeve',
#   'solid',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'black'],
#  ['crochet',
#   'lace',
#   'inserts',
#   'panels',
#   'imagine',
#   'work',
#   'took',
#   'put',
#   'together',
#   'must'],
#  ['kaaryah',
#   'formal',
#   'sleeveless',
#   'solid',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'maroon',
#   'rs'],
#  ['kaaryah',
#   'formal',
#   'sleeveless',
#   'solid',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'black',
#   'rs'],
#  ['waves', 'girl', 'dress', 'party', 'line', 'price', 'rs'],
#  ['league', 'girl', 'shift', 'dress', 'online', 'buy', 'black', 'rs'],
#  ['oxolloxo',
#   'girl',
#   'line',
#   'dress',
#   'online',
#   'buy',
#   'black',
#   'rs',
#   'india'],
#  ['kaaryah',
#   'casual',
#   'sleeveless',
#   'solid',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'blue',
#   'rs'],
#  ['kaaryah', 'casual', 'sleeve', 'printed', 'women', 'top', 'online', 'buy'],
#  ['addiction',
#   'casual',
#   'short',
#   'sleeve',
#   'printed',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'navy'],
#  ['colors',
#   'couture',
#   'casual',
#   'short',
#   'sleeve',
#   'printed',
#   'women',
#   'top',
#   'online',
#   'buy'],
#  ['life',
#   'shoppers',
#   'stop',
#   'casual',
#   'short',
#   'sleeve',
#   'applique',
#   'women',
#   'top',
#   'online'],
#  ['life',
#   'shoppers',
#   'stop',
#   'casual',
#   'sleeveless',
#   'solid',
#   'women',
#   'top',
#   'online',
#   'buy'],
#  ['pieces',
#   'wearyourshine',
#   'please',
#   'note',
#   'diamonds',
#   'clarity',
#   'vssi',
#   'color',
#   'jk',
#   'pc'],
#  ['top',
#   'roadster',
#   'short',
#   'printed',
#   'blue',
#   'knitted',
#   'round',
#   'neck',
#   'sleeves',
#   'gathersedgy'],
#  ['trend', 'arrest', 'casual', 'sleeve', 'solid', 'women', 'top', 'online'],
#  ['karatcraft', 'duilla', 'ruby', 'gold', 'diamond', 'k', 'ring', 'buy', 'rs'],
#  ['bluestone', 'beatrice', 'white', 'gold', 'diamond', 'pearl', 'k', 'ring'],
#  ['certified',
#   'diamond',
#   'ring',
#   'gold',
#   'studded',
#   'carat',
#   'products',
#   'hallmark'],
#  ['pearl', 'gold', 'kuberbox', 'sortilège', 'diamond', 'white', 'k', 'ring'],
#  ['gold',
#   'jacknjewel',
#   'ring',
#   'natural',
#   'stone',
#   'made',
#   'hallmark',
#   'products',
#   'certified'],
#  ['faballey',
#   'casual',
#   'full',
#   'sleeve',
#   'solid',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'red'],
#  ['elegant',
#   'stitched',
#   'georgette',
#   'soft',
#   'net',
#   'western',
#   'tops',
#   'available',
#   'l',
#   'xl'],
#  ['elegant',
#   'stitched',
#   'georgette',
#   'soft',
#   'net',
#   'western',
#   'tops',
#   'available',
#   'l',
#   'xl'],
#  ['top',
#   'showoff',
#   'showcase',
#   'true',
#   'beauty',
#   'slipping',
#   'purple',
#   'coloured',
#   'stylish',
#   'comes'],
#  ['bedazzle',
#   'vivity',
#   'brands',
#   'owned',
#   'managed',
#   'karishma',
#   'fashions',
#   'mumbai',
#   'products',
#   'personify'],
#  ['yepme',
#   'casual',
#   'sleeveless',
#   'solid',
#   'women',
#   'top',
#   'online',
#   'buy',
#   'purple',
#   'rs'],
#  ['product',
#   'wonderland',
#   'important',
#   'note',
#   'color',
#   'parts',
#   'may',
#   'vary',
#   'shown',
#   'image'],
#  ['product',
#   'humans',
#   'zombiecon',
#   'important',
#   'note',
#   'color',
#   'parts',
#   'may',
#   'vary'],
#  ['copper', 'jug', 'glass', 'set', 'dungri', 'india', 'craft'],
#  ['copper', 'jug', 'glass', 'set', 'dungri', 'india', 'craft'],
#  ['one', 'tempered', 'glass', 'newworld', 'rtne', 'pack', 'xiaomi', 'mi'],
#  ['one',
#   'tempered',
#   'glass',
#   'newworld',
#   'rtne',
#   'pack',
#   'intex',
#   'aqua',
#   'sense'],
#  ['polypropylene',
#   'stick',
#   'folders',
#   'hariom',
#   'enterprises',
#   'paper',
#   'made',
#   'virgin',
#   'transparent',
#   'material'],
#  ['plastic',
#   'file',
#   'polypropylene',
#   'cover',
#   'hariom',
#   'enterprises',
#   'compatible',
#   'paper',
#   'size'],
#  ['bulb', 'led', 'bft', 'w', 'white', 'light', 'pack', 'lighting'],
#  ['pen',
#   'lamy',
#   'screen',
#   'ball',
#   'metalic',
#   'stylus',
#   'red',
#   'material',
#   'aluminium',
#   'color'],
#  ['soap',
#   'glycerine',
#   'lakshadi',
#   'skin',
#   'medimix',
#   'transparent',
#   'fragrance',
#   'bathing',
#   'dry',
#   'ideal'],
#  ['solid',
#   'men',
#   'waistcoat',
#   'wash',
#   'american',
#   'elm',
#   'pattern',
#   'occasion',
#   'casual',
#   'ideal'],
#  ['white', 'bulb', 'led', 'bft', 'w', 'cool', 'pack', 'light'],
#  ['menu', 'power', 'warranty', 'microwave', 'cm', 'cook', 'demo', 'indian'],
#  ['bulb', 'led', 'bft', 'w', 'pack', 'white', 'light', 'better'],
#  ['checkered',
#   'men',
#   'waistcoat',
#   'raymond',
#   'cotton',
#   'color',
#   'blue',
#   'pattern',
#   'ideal',
#   'additional'],
#  ['bulb', 'led', 'bft', 'w', 'white', 'pack', 'light', 'better'],
#  ['usb',
#   'cable',
#   'charger',
#   'warranty',
#   'vc',
#   'furst',
#   'adapter',
#   'dzire',
#   'battery'],
#  ['usb', 'cable', 'charger', 'warranty', 'x', 'gen', 'furst', 'adapter', 'mt'],
#  ['usb',
#   'cable',
#   'charger',
#   'warranty',
#   'vibe',
#   'furst',
#   'adapter',
#   'lnvo',
#   'battery'],
#  ['warranty',
#   'usb',
#   'cable',
#   'charger',
#   'covered',
#   'furst',
#   'adapter',
#   'battery'],
#  ['usb',
#   'cable',
#   'charger',
#   'warranty',
#   'sv',
#   'furst',
#   'adapter',
#   'dzire',
#   'battery'],
#  ['usb', 'cable', 'charger', 'warranty', 'furst', 'adapter', 'xp', 'battery'],
#  ['usb',
#   'cable',
#   'charger',
#   'warranty',
#   'sisley',
#   'furst',
#   'adapter',
#   'lnvo',
#   'battery'],
#  ['usb',
#   'cable',
#   'charger',
#   'warranty',
#   'one',
#   'dual',
#   'sim',
#   'furst',
#   'adapter',
#   'battery'],
#  ['usb',
#   'cable',
#   'charger',
#   'warranty',
#   'core',
#   'prime',
#   'furst',
#   'adapter',
#   'battery'],
#  ['usb',
#   'cable',
#   'charger',
#   'warranty',
#   'miro',
#   'furst',
#   'adapter',
#   'xp',
#   'battery'],
#  ['kalabhawan',
#   'stair',
#   'sculpture',
#   'showpiece',
#   'cm',
#   'buy',
#   'rs',
#   'online'],
#  ['serebroarts',
#   'decorative',
#   'platter',
#   'ring',
#   'ceremony',
#   'wedding',
#   'engagement',
#   'iron',
#   'gold',
#   'silver'],
#  ['sunrise', 'showpiece', 'cm', 'buy', 'rs', 'online', 'best', 'prices'],
#  ['sassy',
#   'stripes',
#   'full',
#   'sleeve',
#   'printed',
#   'women',
#   'jacket',
#   'online',
#   'buy',
#   'multicolor'],
#  ['party',
#   'women',
#   'kurti',
#   'embroidered',
#   'us',
#   'jayanti',
#   'sarees',
#   'sleeve',
#   'wash',
#   'contact'],
#  ['printed', 'cm', 'jmd', 'cushions', 'cover', 'cotton', 'pack', 'multicolor'],
#  ['pyjama',
#   'set',
#   'top',
#   'baby',
#   'girl',
#   'printed',
#   'green',
#   'mom',
#   'kid',
#   'cotton'],
#  ['red',
#   'umbrella',
#   'heart',
#   'reckonon',
#   'inch',
#   'ideal',
#   'women',
#   'men',
#   'girls'],
#  ['shoe',
#   'material',
#   'weight',
#   'use',
#   'zebra',
#   'outdoors',
#   'ideal',
#   'girls',
#   'occasion',
#   'sports'],
#  ['printed', 'cm', 'jmd', 'cushions', 'cover', 'cotton', 'pack', 'multicolor'],
#  ['devinez', 'g', 'cm', 'jasmine', 'tea', 'tree', 'package', 'home', 'liquid'],
#  ['cm', 'kripa', 'printed', 'cushions', 'cover', 'width', 'pack', 'grey'],
#  ['rosemoore', 'gel', 'home', 'air', 'freshener', 'g', 'package', 'price'],
#  ['oil',
#   'eucalyptus',
#   'fresh',
#   'aroma',
#   'itiha',
#   'essential',
#   'potpourri',
#   'ml',
#   'roses',
#   'home'],
#  ['oil',
#   'essential',
#   'eucalyptus',
#   'citronella',
#   'ml',
#   'itiha',
#   'potpourri',
#   'home',
#   'liquid',
#   'air'],
#  ['itiha', 'ml', 'mandarin', 'fresh', 'roses', 'package', 'aroma', 'oil'],
#  ['top',
#   'pyjama',
#   'set',
#   'baby',
#   'girl',
#   'printed',
#   'blue',
#   'grey',
#   'mom',
#   'kid'],
#  ['shorts',
#   'gym',
#   'mynte',
#   'solid',
#   'women',
#   'cycling',
#   'swim',
#   'dry',
#   'great',
#   'running'],
#  ['shorts',
#   'solid',
#   'women',
#   'cycling',
#   'gym',
#   'swim',
#   'wear',
#   'photo',
#   'mynte'],
#  ['hair',
#   'conditioner',
#   'tresemme',
#   'naturals',
#   'nourishing',
#   'moisture',
#   'aloe',
#   'vera',
#   'avocado',
#   'ideal'],
#  ['mug',
#   'ceramic',
#   'akup',
#   'mugs',
#   'love',
#   'music',
#   'ml',
#   'coffee',
#   'quality'],
#  ['shorts',
#   'solid',
#   'women',
#   'cycling',
#   'gym',
#   'swim',
#   'wear',
#   'photo',
#   'mynte'],
#  ['mug', 'ceramic', 'akup', 'mugs', 'beautiful', 'ml', 'coffee', 'quality'],
#  ['shorts',
#   'gym',
#   'mynte',
#   'solid',
#   'women',
#   'cycling',
#   'swim',
#   'dry',
#   'great',
#   'running'],
#  ['shorts',
#   'gym',
#   'mynte',
#   'solid',
#   'women',
#   'cycling',
#   'swim',
#   'dry',
#   'great',
#   'running'],
#  ['cm', 'mohanjodero', 'iron', 'showpiece', 'height', 'width', 'weight'],
#  ['hair',
#   'deep',
#   'conditioner',
#   'burt',
#   'bees',
#   'repair',
#   'shea',
#   'grapefruit',
#   'ideal',
#   'boys'],
#  ['shorts',
#   'gym',
#   'mynte',
#   'solid',
#   'women',
#   'cycling',
#   'swim',
#   'dry',
#   'great',
#   'running'],
#  ['mug',
#   'ceramic',
#   'akup',
#   'mugs',
#   'happy',
#   'thanks',
#   'giving',
#   'ml',
#   'coffee'],
#  ['mug',
#   'ceramic',
#   'akup',
#   'mugs',
#   'loves',
#   'music',
#   'ml',
#   'coffee',
#   'quality'],
#  ['shorts',
#   'gym',
#   'mynte',
#   'solid',
#   'women',
#   'cycling',
#   'swim',
#   'dry',
#   'great',
#   'running'],
#  ['mug', 'ceramic', 'akup', 'mugs', 'dream', 'big', 'work', 'hard', 'ml'],
#  ['mug', 'ceramic', 'akup', 'mugs', 'love', 'mom', 'ml', 'coffee', 'quality'],
#  ['mug', 'ceramic', 'akup', 'mugs', 'one', 'gud', 'thing', 'music', 'ml'],
#  ['mug', 'mm', 'ceramic', 'ml', 'safe', 'akup', 'dad', 'daughters'],
#  ['mug', 'ceramic', 'akup', 'mugs', 'happy', 'mothers', 'day', 'ml', 'coffee'],
#  ['mug',
#   'ceramic',
#   'akup',
#   'mugs',
#   'love',
#   'music',
#   'ml',
#   'coffee',
#   'quality'],
#  ['mug', 'ceramic', 'akup', 'mugs', 'keep', 'calm', 'ml', 'coffee', 'quality'],
#  ['mug', 'ceramic', 'akup', 'mugs', 'ur', 'kind', 'ml', 'coffee', 'quality'],
#  ['mug',
#   'ceramic',
#   'akup',
#   'mugs',
#   'love',
#   'dubstep',
#   'ml',
#   'coffee',
#   'quality'],
#  ['mug', 'ceramic', 'akup', 'mugs', 'creid', 'ml', 'coffee', 'quality'],
#  ['warranty', 'operating', 'link', 'speed', 'c', 'white', 'mbps', 'covered'],
#  ['shorts',
#   'gym',
#   'mynte',
#   'solid',
#   'women',
#   'cycling',
#   'swim',
#   'dry',
#   'great',
#   'running'],
#  ['mug',
#   'ceramic',
#   'akup',
#   'mugs',
#   'league',
#   'legends',
#   'ml',
#   'coffee',
#   'quality'],
#  ['hair',
#   'conditioner',
#   'suave',
#   'naturals',
#   'everlasting',
#   'sunshine',
#   'ideal',
#   'boys',
#   'girls',
#   'applied'],
#  ['shorts',
#   'gym',
#   'mynte',
#   'solid',
#   'women',
#   'cycling',
#   'swim',
#   'dry',
#   'great',
#   'running'],
#  ['mug',
#   'ceramic',
#   'akup',
#   'mugs',
#   'life',
#   'living',
#   'ml',
#   'coffee',
#   'quality'],
#  ['shorts',
#   'gym',
#   'mynte',
#   'solid',
#   'women',
#   'cycling',
#   'swim',
#   'dry',
#   'great',
#   'running'],
#  ['shorts',
#   'gym',
#   'mynte',
#   'solid',
#   'women',
#   'cycling',
#   'swim',
#   'dry',
#   'great',
#   'running'],
#  ['shorts',
#   'gym',
#   'mynte',
#   'solid',
#   'women',
#   'cycling',
#   'swim',
#   'dry',
#   'great',
#   'running'],
#  ['shorts',
#   'gym',
#   'mynte',
#   'solid',
#   'women',
#   'cycling',
#   'swim',
#   'dry',
#   'great',
#   'running'],
#  ['mug',
#   'ceramic',
#   'akup',
#   'mugs',
#   'crazy',
#   'women',
#   'ml',
#   'coffee',
#   'quality'],
#  ['mug', 'ceramic', 'akup', 'mugs', 'urr', 'hero', 'ml', 'coffee'],
#  ['hair',
#   'conditioner',
#   'moisture',
#   'dove',
#   'therapy',
#   'daily',
#   'care',
#   'dry',
#   'ml'],
#  ['mug',
#   'ceramic',
#   'akup',
#   'mugs',
#   'love',
#   'stories',
#   'ml',
#   'coffee',
#   'quality'],
#  ['mug', 'ceramic', 'akup', 'mugs', 'happy', 'new', 'year', 'love', 'ml'],
#  ['mug', 'ceramic', 'akup', 'mugs', 'brother', 'ml', 'coffee', 'quality'],
#  ['shorts',
#   'gym',
#   'mynte',
#   'solid',
#   'women',
#   'cycling',
#   'swim',
#   'dry',
#   'great',
#   'running'],
#  ['mug',
#   'ceramic',
#   'akup',
#   'mugs',
#   'without',
#   'rain',
#   'ml',
#   'coffee',
#   'quality'],
#  ['hair',
#   'lavender',
#   'mint',
#   'conditioner',
#   'tea',
#   'tree',
#   'moisturizing',
#   'paul',
#   'mitchell',
#   'unisex'],
#  ['shorts',
#   'solid',
#   'women',
#   'cycling',
#   'gym',
#   'swim',
#   'wear',
#   'photo',
#   'mynte'],
#  ['shorts',
#   'gym',
#   'mynte',
#   'solid',
#   'women',
#   'cycling',
#   'swim',
#   'dry',
#   'great',
#   'running'],
#  ['shorts',
#   'gym',
#   'mynte',
#   'solid',
#   'women',
#   'cycling',
#   'swim',
#   'dry',
#   'great',
#   'running'],
#  ['keyboard',
#   'flexible',
#   'slim',
#   'multimedia',
#   'usb',
#   'warranty',
#   'roq',
#   'wired',
#   'white'],
#  ['brandtrendz',
#   'bellies',
#   'material',
#   'pu',
#   'occasion',
#   'casual',
#   'color',
#   'heel',
#   'height'],
#  ['material',
#   'croslite',
#   'boys',
#   'sandal',
#   'weight',
#   'dirt',
#   'crocs',
#   'sandals',
#   'ideal',
#   'occasion'],
#  ['paint',
#   'decor',
#   'spray',
#   'bottle',
#   'com',
#   'set',
#   'yellow',
#   'series',
#   'model'],
#  ['top',
#   'sleeve',
#   'meril',
#   'casual',
#   'full',
#   'printed',
#   'women',
#   'neck',
#   'pink',
#   'price'],
#  ['electric',
#   'asian',
#   'aura',
#   'burner',
#   'rose',
#   'vanilla',
#   'liquid',
#   'ml',
#   'air',
#   'freshener'],
#  ['niremo',
#   'material',
#   'loafers',
#   'brown',
#   'suede',
#   'sole',
#   'pvc',
#   'shoe',
#   'weight'],
#  ['na',
#   'diamond',
#   'bangle',
#   'gold',
#   'aadyaa',
#   'collections',
#   'alloy',
#   'set',
#   'pack'],
#  ['sleeve',
#   'top',
#   'indricka',
#   'casual',
#   'butterfly',
#   'solid',
#   'women',
#   'cotton',
#   'neck',
#   'blue'],
#  ['synthetic',
#   'material',
#   'shoe',
#   'lining',
#   'weight',
#   'leather',
#   'shoes',
#   'schtaron',
#   'loafers',
#   'occasion'],
#  ['charger', 'clair', 'micromax', 'canvas', 'play', 'battery', 'dual', 'usb'],
#  ['na',
#   'bracelet',
#   'jewellery',
#   'golden',
#   'herbal',
#   'bead',
#   'diamond',
#   'alloy',
#   'wood'],
#  ['loafers',
#   'brandtrendz',
#   'material',
#   'pu',
#   'occasion',
#   'casual',
#   'color',
#   'blue',
#   'heel',
#   'height'],
#  ['top',
#   'short',
#   'sleeve',
#   'casual',
#   'printed',
#   'women',
#   'riot',
#   'jeans',
#   'neck',
#   'round'],
#  ['top',
#   'sleeve',
#   'meril',
#   'casual',
#   'full',
#   'printed',
#   'women',
#   'neck',
#   'royal',
#   'blue'],
#  ['wheel', 'cleaner', 'mount', 'nano', 'mn', 'surfaces', 'ml', 'rim'],
#  ['loafers',
#   'back',
#   'open',
#   'loafer',
#   'casual',
#   'blue',
#   'steppings',
#   'comfortable',
#   'price'],
#  ['maruti',
#   'ciaz',
#   'car',
#   'carmity',
#   'grill',
#   'cover',
#   'rn',
#   'plastic',
#   'model'],
#  ['charge',
#   'load',
#   'phocos',
#   'mppt',
#   'solar',
#   'controller',
#   'battery',
#   'warranty',
#   'display'],
#  ...]

# %%
for i in range(len(model_df.index)):
    model_df.at[i,'tags'] = token_lists[i]

# %%
model_df
# Out:
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# 1          FabHomeDecor Fabric Double Sofa Bed
# 2                                   AW Bellies
# 3          Alisha Solid Women's Cycling Shorts
# 4        Sicons All Purpose Arnica Dog Shampoo
# ...                                        ...
# 19995           WallDesign Small Vinyl Sticker
# 19996  Wallmantra Large Vinyl Stickers Sticker
# 19997  Elite Collection Medium Acrylic Sticker
# 19998  Elite Collection Medium Acrylic Sticker
# 19999  Elite Collection Medium Acrylic Sticker
#
#                                              description  \
# 0      Key Features of Alisha Solid Women's Cycling S...
# 1      FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2      Key Features of AW Bellies Sandals Wedges Heel...
# 3      Key Features of Alisha Solid Women's Cycling S...
# 4      Specifications of Sicons All Purpose Arnica Do...
# ...                                                  ...
# 19995  Buy WallDesign Small Vinyl Sticker for Rs.730 ...
# 19996  Buy Wallmantra Large Vinyl Stickers Sticker fo...
# 19997  Buy Elite Collection Medium Acrylic Sticker fo...
# 19998  Buy Elite Collection Medium Acrylic Sticker fo...
# 19999  Buy Elite Collection Medium Acrylic Sticker fo...
#
#                                                     tags
# 0      [shorts, solid, women, cycling, alisha, cotton...
# 1      [product, sofa, color, bed, warranty, material...
# 2      [aw, bellies, heel, material, casual, warranty...
# 3      [shorts, solid, women, cycling, alisha, cotton...
# 4      [sicons, arnica, dog, purpose, shampoo, ml, pe...
# ...                                                  ...
# 19995  [walldesign, small, vinyl, sticker, buy, rs, o...
# 19996  [wallmantra, large, vinyl, stickers, sticker, ...
# 19997  [elite, collection, medium, acrylic, sticker, ...
# 19998  [elite, collection, medium, acrylic, sticker, ...
# 19999  [elite, collection, medium, acrylic, sticker, ...
#
# [20000 rows x 3 columns]

# %% [markdown]
# #### Delete missing values (should be done in the first couple of cells)

# %%
model_df.isnull().sum()
# Out:
# product_name    0
# description     2
# tags            0
# dtype: int64

# %%
model_df.dropna(inplace=True)

# %% [markdown]
# #### dtype

# %%
type(model_df['tags'].iloc[0])
# Out:
# list

# %% [markdown]
# # Some analyzing of the words

# %%
# descriptions = model_df.description.str.cat(sep=' ')
# tokens = word_tokenize(descriptions)
# vocab = set(tokens)

# freq_dist = nltk.FreqDist(tokens)
# sorted(freq_dist, key=freq_dist.__getitem__, reverse=True)[0:10]

# stop_words = set(stopwords.words('english'))
# tokens = [w for w in tokens if not w in stop_words]

# %%
# [....]

# %%
all_tags = []
for i in token_lists:
    for j in i:
        all_tags.append(j)

# %%
cv = CountVectorizer(tokenizer=lambda x:x.split())
tag_dtm = cv.fit_transform(all_tags)
print(("There are {} unique tags").format(tag_dtm.shape[1]))

# %%
# Create and generate a word cloud image of just one string/description
wordcloud = WordCloud(background_color="white").generate(test_string)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
tags_counted_and_sorted = pd.DataFrame({'tag': all_tags}).groupby('tag').size().reset_index().sort_values(0, ascending=False)
tags_counted_and_sorted

# %%
tags_counted_and_sorted[:10].plot.barh(x='tag', y=0, figsize=(12,8))

# %% [markdown]
# # Machine Learning - Multilabel Classification
#
# ---

# %% [markdown]
# ## Baseline
#
# The baseline is actually what I did in the function above. Tags are generated based on the occurunce of a word. The next step is to actually let the Machine Learning Multi-label classification Technique create these tags itself.

# %% [markdown]
# ## Preprocessing

# %%
# there are a total of 19998 rows and 3 different columns. 
model_df.shape
# Out:
# (19998, 3)

# %%
n = 2000

# %%
target_variable = model_df['tags'][:n]

# %%
mlb = MultiLabelBinarizer()
target_variable = mlb.fit_transform(target_variable)

# %%
mlb.classes_
# Out:
# array(['_brn', 'aa', 'aadivasi', ..., 'zoysia', 'zte', 'zunia'],
#       dtype=object)

# %% [markdown]
# ### TfidfVectorizer
#
# ---
#
# This method tokenizes documents/texts, learns the vocabulary and inverses the document frequency weightings and allows you to encode new documents.
#
# We will import this method from <b> sklearn.feature_extraction.text </b>.
# There are a lot of different parameters:
#
# - <b>lowercase;</b> Convert all characters to lowercase, which in our case will be handy
# - <b>stop_words;</b> If a string, it is passed to _check_stop_list and the appropriate stop list is returned
# - <b>ngram_range;</b> The lower and upper boundary of the range of n-values for different n-grams to be extracted
# - <b>max_features;</b> If not None, build a vocabulary that only consider the top max_features ordered by term frequency across the corpus

# %%
# Initialise the vectorizer
vectorizer = TfidfVectorizer(strip_accents='unicode', 
                             analyzer='word', 
                             ngram_range=(1,3), 
#                              max_features=1000,
                             stop_words='english',
                             token_pattern=r'\w{3,}'
                            )


# fit the independent features
independent_variable = vectorizer.fit_transform(model_df['description'][:n])

print('Independent variable shape: {}'.format(independent_variable.shape))
print('Target variable shape: {}'.format(target_variable.shape))
# Out:
# Independent variable shape: (2000, 78536)
# Target variable shape: (2000, 3039)

# %%
vectorizer.vocabulary_

# %% [markdown]
# #### Train/test sets

# %%
# split the data into training en testing sets
X_train, X_test, y_train, y_test = train_test_split(
                                        independent_variable, 
                                        target_variable, 
                                        test_size=0.2, 
                                        random_state=42, 
                                        )

# %%
print('X train shape: {}'.format(X_train.shape))
print('y train shape: {}'.format(y_train.shape))

print('------------------------------')

print('X test shape: {}'.format(X_test.shape))
print('y test shape: {}'.format(y_test.shape))
# Out:
# X train shape: (1600, 78536)
# y train shape: (1600, 3039)
# ------------------------------
# X test shape: (400, 78536)
# y test shape: (400, 3039)

# %% [markdown]
# # Model building
#
# ---
#
# ### Pipeline
# ### LinearSVC

# %%
Linear_pipeline = Pipeline([
                ('clf', OneVsRestClassifier(LinearSVC(
                                                class_weight='balanced',
                                                random_state=42,
                                                tol=1e-1,
                                                C=8.385), 
                                                n_jobs=-1)),
            ])

# %%
Linear_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('clf',
#                  OneVsRestClassifier(estimator=LinearSVC(C=8.385,
#                                                          class_weight='balanced',
#                                                          dual=True,
#                                                          fit_intercept=True,
#                                                          intercept_scaling=1,
#                                                          loss='squared_hinge',
#                                                          max_iter=1000,
#                                                          multi_class='ovr',
#                                                          penalty='l2',
#                                                          random_state=42,
#                                                          tol=0.1, verbose=0),
#                                      n_jobs=-1))],
#          verbose=False)

# %%
prediction = Linear_pipeline.predict(X_test)

# %%
print('Accuracy for LinearSVC is {}'.format(accuracy_score(y_test, prediction)))
# Out:
# Accuracy for LinearSVC is 0.37

# %% [markdown]
# ### Logistic Regression

# %%
Logistic_pipeline = Pipeline([
                ('clf', OneVsRestClassifier(LogisticRegression(
                                                class_weight='balanced',
                                                random_state=0,
                                                tol=1e-1,
                                                C=8.385), 
                                                n_jobs=-1)),
            ])

# %%
Logistic_pipeline.fit(X_train, y_train)

# %%
prediction_2 = Logistic_pipeline.predict(X_test)

# %%
print('Accuracy for LinearSVC is {}'.format(accuracy_score(y_test, prediction_2)))

# %% [markdown]
# ### MultinomialNB (Naive Bayes)

# %%
NB_pipeline = Pipeline([
                ('clf', OneVsRestClassifier(MultinomialNB(
                                                fit_prior=True, 
                                                class_prior=None))),
            ])

# %%
# NB_pipeline.fit(X_train, y_train)

# %%
prediction_3 = NB_pipeline.predict(X_test)

# %%
print('Accuracy for Naive Bayes is {}'.format(accuracy_score(y_test, prediction_3)))

# %% [markdown]
# # Comparison

# %%
# model_names = ['LinearSVC','LogisticRegression','Naive Bayes']
model_names = ['LinearSVC']
scores_10 = [0.3575,0.233,0.0535] #scores tested with half of the dataset
scores_20 = [0.379166] #scores with the whole dataset

# %%
score_frame = pd.DataFrame({'Model': model_names, 'Accuracy Score 20k': scores_20})
score_frame

# %%
sns.factorplot(y='Model',x='Accuracy Score 20k',data=score_frame,kind='bar',aspect=2)
plt.show()

# %% [markdown]
# # Model testing

# %%
string_1 = ['Key Features of Alisha Solid Womens Cycling Shorts Cotton Lycra Navy, Red, Navy,Specifications of Alisha Solid Womens Cycling Shorts Shorts Details Number of Contents in Sales Package Pack of 3 Fabric Cotton Lycra Type Cycling Shorts General Details Pattern Solid Ideal For Womens Fabric Care Gentle Machine Wash in Lukewarm Water, Do Not Bleach Additional Details Style Code ALTHT_3P_21 In the Box 3 shorts']

# %%
model_string_1 = vectorizer.transform(string_1)
Linear_pipeline.predict(model_string_1)
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]])

# %% [markdown]
# ### Predicted/generated tags for product description 1

# %%
predicted_tags = mlb.inverse_transform(Linear_pipeline.predict(model_string_1))
predicted_tags
# Out:
# [('alisha', 'cotton', 'cycling', 'lycra', 'navy', 'red', 'shorts', 'solid')]

# %% [markdown]
# ### Tags created by the baseline

# %%
baseline_tags = model_df['tags'][0]
baseline_tags

# %% [markdown]
# ---
# ## Add tags created by the ML to a whole new dataframe

# %%
submission_df = model_df.drop(columns=['tags','product_name'])
sample_df = submission_df[:n]
sample_df.head(5)
# Out:
#                                          description
# 0  Key Features of Alisha Solid Women's Cycling S...
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2  Key Features of AW Bellies Sandals Wedges Heel...
# 3  Key Features of Alisha Solid Women's Cycling S...
# 4  Specifications of Sicons All Purpose Arnica Do...

# %%
description_variable = vectorizer.fit_transform(sample_df['description'])
prediction_values = mlb.inverse_transform(Linear_pipeline.predict(description_variable))
sample_df['tags'] = np.asarray(prediction_values)
sample_df.head(5)
# Out:
#                                          description  \
# 0  Key Features of Alisha Solid Women's Cycling S...
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2  Key Features of AW Bellies Sandals Wedges Heel...
# 3  Key Features of Alisha Solid Women's Cycling S...
# 4  Specifications of Sicons All Purpose Arnica Do...
#
#                                                 tags
# 0  (alisha, cotton, cycling, lycra, navy, red, sh...
# 1  (avoid, bed, black, color, double, finish, mat...
# 2  (aw, bellies, casual, heel, material, pair, sh...
# 3  (alisha, black, cotton, cycling, lycra, red, s...
# 4  (arnica, brand, dog, ml, pet, purpose, quantit...
